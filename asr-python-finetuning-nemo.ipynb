# %% [markdown]
# <img src="http://developer.download.nvidia.com/notebooks/dlsw-notebooks/riva_asr_asr-python-advanced-finetune-am-conformer-ctc-tao-finetuning/nvidia_logo.png" style="width: 90px; float: right;">
#
# # How to Fine-Tune a Riva ASR Acoustic Model with NVIDIA NeMo
# This tutorial walks you through how to fine-tune an NVIDIA Riva ASR acoustic model with NVIDIA NeMo.

# %% [markdown]
# ## NVIDIA Riva Overview
#
# NVIDIA Riva is a GPU-accelerated SDK for building speech AI applications that are customized for your use case and deliver real-time performance. <br/>
# Riva offers a rich set of speech and natural language understanding services such as:
#
# - Automated speech recognition (ASR).
# - Text-to-Speech synthesis (TTS).
# - A collection of natural language processing (NLP) services, such as named entity recognition (NER), punctuation, and intent classification.
#
# In this tutorial, we will fine-tune a Riva ASR acoustic model with NeMo. <br>
# To understand the basics of Riva ASR APIs, refer to [Getting started with Riva ASR in Python](https://github.com/nvidia-riva/tutorials/blob/stable/asr-python-basics.ipynb). <br>
#
# For more information about Riva, refer to the [Riva developer documentation](https://developer.nvidia.com/riva).

# %% [markdown]
# ## NeMo (Neural Modules)
# [NVIDIA NeMo](https://developer.nvidia.com/nvidia-nemo) is an open-source framework for building, training, and fine-tuning GPU-accelerated speech AI and natural language understanding (NLU) models with a simple Python interface. You may visit the GitHub page of [NeMo](https://github.com/NVIDIA/NeMo) and follow the instructions to setup NeMo.

# %%
"""
You can run either this notebook locally (if you have all the dependencies and a GPU) or on Google Colab.

Instructions for setting up Colab are as follows:
1. Open a new Python 3 notebook.
2. Import this notebook from GitHub (File -> Upload Notebook -> "GITHUB" tab -> copy/paste GitHub URL)
3. Connect to an instance with a GPU (Runtime -> Change runtime type -> select "GPU" for hardware accelerator)
4. Run this cell to set up dependencies.
5. Restart the runtime (Runtime -> Restart Runtime) for any upgraded packages to take effect
"""

# Install dependencies
# !pip install wget
# !apt-get install sox libsndfile1 ffmpeg libsox-fmt-mp3
# !pip install text-unidecode
# !pip install matplotlib>=3.3.2
# !pip install Cython

## Install NeMo
BRANCH = 'main'
# !python -m pip install git+https://github.com/NVIDIA/NeMo.git@$BRANCH#egg=nemo_toolkit[all]

"""
Remember to restart the runtime for the kernel to pick up any upgraded packages (e.g. matplotlib)!
Alternatively, you can uncomment the exit() below to crash and restart the kernel, in the case
that you want to use the "Run All Cells" (or similar) option.
"""
# exit()
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting wget
#   Downloading wget-3.2.zip (10 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: wget
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9674 sha256=6b68f1ee8a11df69a45f227e5e569c7a6ebfa9cbb1b339f572552b9362e4f1a4
#   Stored in directory: /root/.cache/pip/wheels/bd/a8/c3/3cf2c14a1837a4e04bd98631724e81f33f462d86a1d895fae0
# Successfully built wget
# Installing collected packages: wget
# Successfully installed wget-3.2
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libsndfile1 is already the newest version (1.0.28-7ubuntu0.1).
# ffmpeg is already the newest version (7:4.2.7-0ubuntu0.1).
# The following additional packages will be installed:
#   libid3tag0 libmad0 libmagic-mgc libmagic1 libopencore-amrnb0
#   libopencore-amrwb0 libsox-fmt-alsa libsox-fmt-base libsox3
# Suggested packages:
#   file libsox-fmt-all
# The following NEW packages will be installed:
#   libid3tag0 libmad0 libmagic-mgc libmagic1 libopencore-amrnb0
#   libopencore-amrwb0 libsox-fmt-alsa libsox-fmt-base libsox-fmt-mp3 libsox3
#   sox
# 0 upgraded, 11 newly installed, 0 to remove and 23 not upgraded.
# Need to get 917 kB of archives.
# After this operation, 8,035 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal/main amd64 libmagic-mgc amd64 1:5.38-4 [218 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal/main amd64 libmagic1 amd64 1:5.38-4 [75.9 kB]
# Get:3 http://archive.ubuntu.com/ubuntu focal/universe amd64 libid3tag0 amd64 0.15.1b-14 [31.3 kB]
# Get:4 http://archive.ubuntu.com/ubuntu focal/universe amd64 libmad0 amd64 0.15.1b-10ubuntu1 [63.1 kB]
# Get:5 http://archive.ubuntu.com/ubuntu focal/universe amd64 libopencore-amrnb0 amd64 0.1.5-1 [94.8 kB]
# Get:6 http://archive.ubuntu.com/ubuntu focal/universe amd64 libopencore-amrwb0 amd64 0.1.5-1 [49.1 kB]
# Get:7 http://archive.ubuntu.com/ubuntu focal/universe amd64 libsox3 amd64 14.4.2+git20190427-2 [226 kB]
# Get:8 http://archive.ubuntu.com/ubuntu focal/universe amd64 libsox-fmt-alsa amd64 14.4.2+git20190427-2 [10.5 kB]
# Get:9 http://archive.ubuntu.com/ubuntu focal/universe amd64 libsox-fmt-base amd64 14.4.2+git20190427-2 [31.5 kB]
# Get:10 http://archive.ubuntu.com/ubuntu focal/universe amd64 libsox-fmt-mp3 amd64 14.4.2+git20190427-2 [15.9 kB]
# Get:11 http://archive.ubuntu.com/ubuntu focal/universe amd64 sox amd64 14.4.2+git20190427-2 [102 kB]
# Fetched 917 kB in 0s (7,908 kB/s)
# Selecting previously unselected package libmagic-mgc.
# (Reading database ... 129504 files and directories currently installed.)
# Preparing to unpack .../00-libmagic-mgc_1%3a5.38-4_amd64.deb ...
# Unpacking libmagic-mgc (1:5.38-4) ...
# Selecting previously unselected package libmagic1:amd64.
# Preparing to unpack .../01-libmagic1_1%3a5.38-4_amd64.deb ...
# Unpacking libmagic1:amd64 (1:5.38-4) ...
# Selecting previously unselected package libid3tag0:amd64.
# Preparing to unpack .../02-libid3tag0_0.15.1b-14_amd64.deb ...
# Unpacking libid3tag0:amd64 (0.15.1b-14) ...
# Selecting previously unselected package libmad0:amd64.
# Preparing to unpack .../03-libmad0_0.15.1b-10ubuntu1_amd64.deb ...
# Unpacking libmad0:amd64 (0.15.1b-10ubuntu1) ...
# Selecting previously unselected package libopencore-amrnb0:amd64.
# Preparing to unpack .../04-libopencore-amrnb0_0.1.5-1_amd64.deb ...
# Unpacking libopencore-amrnb0:amd64 (0.1.5-1) ...
# Selecting previously unselected package libopencore-amrwb0:amd64.
# Preparing to unpack .../05-libopencore-amrwb0_0.1.5-1_amd64.deb ...
# Unpacking libopencore-amrwb0:amd64 (0.1.5-1) ...
# Selecting previously unselected package libsox3:amd64.
# Preparing to unpack .../06-libsox3_14.4.2+git20190427-2_amd64.deb ...
# Unpacking libsox3:amd64 (14.4.2+git20190427-2) ...
# Selecting previously unselected package libsox-fmt-alsa:amd64.
# Preparing to unpack .../07-libsox-fmt-alsa_14.4.2+git20190427-2_amd64.deb ...
# Unpacking libsox-fmt-alsa:amd64 (14.4.2+git20190427-2) ...
# Selecting previously unselected package libsox-fmt-base:amd64.
# Preparing to unpack .../08-libsox-fmt-base_14.4.2+git20190427-2_amd64.deb ...
# Unpacking libsox-fmt-base:amd64 (14.4.2+git20190427-2) ...
# Selecting previously unselected package libsox-fmt-mp3:amd64.
# Preparing to unpack .../09-libsox-fmt-mp3_14.4.2+git20190427-2_amd64.deb ...
# Unpacking libsox-fmt-mp3:amd64 (14.4.2+git20190427-2) ...
# Selecting previously unselected package sox.
# Preparing to unpack .../10-sox_14.4.2+git20190427-2_amd64.deb ...
# Unpacking sox (14.4.2+git20190427-2) ...
# Setting up libmagic-mgc (1:5.38-4) ...
# Setting up libmagic1:amd64 (1:5.38-4) ...
# Setting up libid3tag0:amd64 (0.15.1b-14) ...
# Setting up libopencore-amrwb0:amd64 (0.1.5-1) ...
# Setting up libmad0:amd64 (0.15.1b-10ubuntu1) ...
# Setting up libopencore-amrnb0:amd64 (0.1.5-1) ...
# Setting up libsox3:amd64 (14.4.2+git20190427-2) ...
# Setting up libsox-fmt-alsa:amd64 (14.4.2+git20190427-2) ...
# Setting up libsox-fmt-base:amd64 (14.4.2+git20190427-2) ...
# Setting up libsox-fmt-mp3:amd64 (14.4.2+git20190427-2) ...
# Setting up sox (14.4.2+git20190427-2) ...
# Processing triggers for libc-bin (2.31-0ubuntu9.9) ...
# Processing triggers for man-db (2.9.1-1) ...
# Processing triggers for mime-support (3.64ubuntu1) ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: text-unidecode in /usr/local/lib/python3.8/dist-packages (1.3)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting nemo_toolkit[all]
#   Cloning https://github.com/NVIDIA/NeMo.git (to revision main) to /tmp/pip-install-7jix5ew2/nemo-toolkit_28e9aa44358c4a4a85ccb2da19455851
#   Running command git clone --filter=blob:none --quiet https://github.com/NVIDIA/NeMo.git /tmp/pip-install-7jix5ew2/nemo-toolkit_28e9aa44358c4a4a85ccb2da19455851
#   Resolved https://github.com/NVIDIA/NeMo.git to commit 12b3bac2124464d7751a204862554082be9bae07
#   Preparing metadata (setup.py) ... done
# Collecting huggingface_hub
#   Downloading huggingface_hub-0.11.1-py3-none-any.whl (182 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.4/182.4 KB 10.2 MB/s eta 0:00:00
# Requirement already satisfied: numba in /usr/local/lib/python3.8/dist-packages (from nemo_toolkit[all]) (0.56.4)
# Collecting numpy>=1.22
#   Downloading numpy-1.24.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 78.8 MB/s eta 0:00:00
# Collecting onnx>=1.7.0
#   Downloading onnx-1.13.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 105.4 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.8/dist-packages (from nemo_toolkit[all]) (2.8.2)
# Collecting ruamel.yaml
#   Downloading ruamel.yaml-0.17.21-py3-none-any.whl (109 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.5/109.5 KB 1.7 MB/s eta 0:00:00
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.8/dist-packages (from nemo_toolkit[all]) (1.0.2)
# Collecting setuptools==59.5.0
#   Downloading setuptools-59.5.0-py3-none-any.whl (952 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 952.4/952.4 KB 72.1 MB/s eta 0:00:00
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.8/dist-packages (from nemo_toolkit[all]) (2.9.1)
# Requirement already satisfied: text-unidecode in /usr/local/lib/python3.8/dist-packages (from nemo_toolkit[all]) (1.3)
# Requirement already satisfied: torch in /usr/local/lib/python3.8/dist-packages (from nemo_toolkit[all]) (1.13.1+cu116)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.8/dist-packages (from nemo_toolkit[all]) (4.64.1)
# Requirement already satisfied: wget in /usr/local/lib/python3.8/dist-packages (from nemo_toolkit[all]) (3.2)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.8/dist-packages (from nemo_toolkit[all]) (1.14.1)
# Collecting black==19.10b0
#   Downloading black-19.10b0-py36-none-any.whl (97 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.5/97.5 KB 15.4 MB/s eta 0:00:00
# Collecting click==8.0.2
#   Downloading click-8.0.2-py3-none-any.whl (97 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.6/97.6 KB 16.0 MB/s eta 0:00:00
# Collecting isort[requirements]<5
#   Downloading isort-4.3.21-py2.py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 KB 5.2 MB/s eta 0:00:00
# Collecting parameterized
#   Downloading parameterized-0.8.1-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: pytest in /usr/local/lib/python3.8/dist-packages (from nemo_toolkit[all]) (3.6.4)
# Collecting pytest-runner
#   Using cached pytest_runner-6.0.0-py3-none-any.whl (7.2 kB)
# Requirement already satisfied: sphinx in /usr/local/lib/python3.8/dist-packages (from nemo_toolkit[all]) (3.5.4)
# Collecting sphinxcontrib-bibtex
#   Downloading sphinxcontrib_bibtex-2.5.0-py3-none-any.whl (39 kB)
# Collecting wandb
#   Downloading wandb-0.13.9-py2.py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 85.2 MB/s eta 0:00:00
# Requirement already satisfied: inflect in /usr/local/lib/python3.8/dist-packages (from nemo_toolkit[all]) (2.1.0)
# Requirement already satisfied: regex in /usr/local/lib/python3.8/dist-packages (from nemo_toolkit[all]) (2022.6.2)
# Collecting hydra-core<1.3,>=1.2.0
#   Downloading hydra_core-1.2.0-py3-none-any.whl (151 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.1/151.1 KB 23.9 MB/s eta 0:00:00
# Collecting omegaconf<2.3,>=2.2
#   Downloading omegaconf-2.2.3-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.3/79.3 KB 12.6 MB/s eta 0:00:00
# Collecting pytorch-lightning<1.9.0,>=1.8.6
#   Downloading pytorch_lightning-1.8.6-py3-none-any.whl (800 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 800.3/800.3 KB 58.7 MB/s eta 0:00:00
# Collecting pyyaml<6
#   Downloading PyYAML-5.4.1-cp38-cp38-manylinux1_x86_64.whl (662 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 662.4/662.4 KB 62.0 MB/s eta 0:00:00
# Collecting torchmetrics>=0.11.0
#   Downloading torchmetrics-0.11.0-py3-none-any.whl (512 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 512.4/512.4 KB 54.3 MB/s eta 0:00:00
# Collecting transformers<=4.21.2,>=4.0.1
#   Downloading transformers-4.21.2-py3-none-any.whl (4.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 89.6 MB/s eta 0:00:00
# Collecting webdataset<=0.1.62,>=0.1.48
#   Downloading webdataset-0.1.62-py3-none-any.whl (32 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (from nemo_toolkit[all]) (1.3.5)
# Collecting sacremoses>=0.0.43
#   Downloading sacremoses-0.0.53.tar.gz (880 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 880.6/880.6 KB 76.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting sentencepiece<1.0.0
#   Downloading sentencepiece-0.1.97-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 80.7 MB/s eta 0:00:00
# Collecting youtokentome>=1.0.5
#   Downloading youtokentome-1.0.6-cp38-cp38-manylinux2010_x86_64.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 96.2 MB/s eta 0:00:00
# Collecting braceexpand
#   Downloading braceexpand-0.1.7-py2.py3-none-any.whl (5.9 kB)
# Requirement already satisfied: editdistance in /usr/local/lib/python3.8/dist-packages (from nemo_toolkit[all]) (0.5.3)
# Collecting g2p_en
#   Downloading g2p_en-2.1.0-py3-none-any.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 88.5 MB/s eta 0:00:00
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.8/dist-packages (from nemo_toolkit[all]) (7.7.1)
# Collecting jiwer
#   Downloading jiwer-2.5.1-py3-none-any.whl (15 kB)
# Collecting kaldi-python-io
#   Downloading kaldi-python-io-1.2.2.tar.gz (8.8 kB)
#   Preparing metadata (setup.py) ... done
# Collecting kaldiio
#   Downloading kaldiio-2.17.2.tar.gz (24 kB)
#   Preparing metadata (setup.py) ... done
# Collecting librosa>=0.9.0
#   Downloading librosa-0.9.2-py3-none-any.whl (214 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.3/214.3 KB 28.9 MB/s eta 0:00:00
# Requirement already satisfied: marshmallow in /usr/local/lib/python3.8/dist-packages (from nemo_toolkit[all]) (3.19.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.8/dist-packages (from nemo_toolkit[all]) (3.2.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from nemo_toolkit[all]) (21.3)
# Collecting pyannote.core
#   Downloading pyannote.core-5.0.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.5/58.5 KB 9.5 MB/s eta 0:00:00
# Collecting pyannote.metrics
#   Downloading pyannote.metrics-3.2.1-py3-none-any.whl (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.4/51.4 KB 8.3 MB/s eta 0:00:00
# Collecting pydub
#   Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.8/dist-packages (from nemo_toolkit[all]) (1.7.3)
# Requirement already satisfied: soundfile in /usr/local/lib/python3.8/dist-packages (from nemo_toolkit[all]) (0.11.0)
# Collecting sox
#   Downloading sox-1.4.1-py2.py3-none-any.whl (39 kB)
# Collecting texterrors
#   Downloading texterrors-0.4.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 60.7 MB/s eta 0:00:00
# Collecting boto3
#   Downloading boto3-1.26.51-py3-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.7/132.7 KB 19.5 MB/s eta 0:00:00
# Collecting einops
#   Downloading einops-0.6.0-py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.6/41.6 KB 6.1 MB/s eta 0:00:00
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.7.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.0/17.0 MB 93.4 MB/s eta 0:00:00
# Collecting fasttext
#   Downloading fasttext-0.9.2.tar.gz (68 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.8/68.8 KB 10.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting flask_restful
#   Downloading Flask_RESTful-0.3.9-py2.py3-none-any.whl (25 kB)
# Collecting ftfy
#   Downloading ftfy-6.1.1-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 KB 7.5 MB/s eta 0:00:00
# Requirement already satisfied: gdown in /usr/local/lib/python3.8/dist-packages (from nemo_toolkit[all]) (4.4.0)
# Collecting gradio==3.4.0
#   Downloading gradio-3.4.0-py3-none-any.whl (5.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 101.0 MB/s eta 0:00:00
# Requirement already satisfied: h5py in /usr/local/lib/python3.8/dist-packages (from nemo_toolkit[all]) (3.1.0)
# Collecting ijson
#   Downloading ijson-3.2.0.post0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.8/114.8 KB 17.5 MB/s eta 0:00:00
# Requirement already satisfied: jieba in /usr/local/lib/python3.8/dist-packages (from nemo_toolkit[all]) (0.42.1)
# Collecting matplotlib
#   Downloading matplotlib-3.6.3-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (9.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.4/9.4 MB 123.0 MB/s eta 0:00:00
# Requirement already satisfied: nltk>=3.6.5 in /usr/local/lib/python3.8/dist-packages (from nemo_toolkit[all]) (3.7)
# Collecting opencc
#   Downloading OpenCC-1.1.6-cp38-cp38-manylinux1_x86_64.whl (778 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 778.2/778.2 KB 68.6 MB/s eta 0:00:00
# Collecting pangu
#   Downloading pangu-4.0.6.1-py3-none-any.whl (6.4 kB)
# Collecting rapidfuzz
#   Downloading rapidfuzz-2.13.7-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 98.3 MB/s eta 0:00:00
# Collecting sacrebleu[ja]
#   Downloading sacrebleu-2.3.1-py3-none-any.whl (118 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.9/118.9 KB 19.3 MB/s eta 0:00:00
# Collecting sentence_transformers
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 KB 14.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting attrdict
#   Downloading attrdict-2.0.1-py2.py3-none-any.whl (9.9 kB)
# Collecting pypinyin
#   Downloading pypinyin-0.48.0-py2.py3-none-any.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 83.5 MB/s eta 0:00:00
# Collecting pypinyin-dict
#   Downloading pypinyin_dict-0.5.0-py2.py3-none-any.whl (9.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 97.9 MB/s eta 0:00:00
# Collecting progress>=1.5
#   Downloading progress-1.6.tar.gz (7.8 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tabulate>=0.8.7 in /usr/local/lib/python3.8/dist-packages (from nemo_toolkit[all]) (0.8.10)
# Collecting textdistance>=4.1.5
#   Downloading textdistance-4.5.0-py3-none-any.whl (31 kB)
# Collecting typed-ast>=1.4.0
#   Downloading typed_ast-1.5.4-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (897 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.2/897.2 KB 71.8 MB/s eta 0:00:00
# Requirement already satisfied: appdirs in /usr/local/lib/python3.8/dist-packages (from black==19.10b0->nemo_toolkit[all]) (1.4.4)
# Requirement already satisfied: attrs>=18.1.0 in /usr/local/lib/python3.8/dist-packages (from black==19.10b0->nemo_toolkit[all]) (22.2.0)
# Requirement already satisfied: toml>=0.9.4 in /usr/local/lib/python3.8/dist-packages (from black==19.10b0->nemo_toolkit[all]) (0.10.2)
# Collecting pathspec<1,>=0.6
#   Downloading pathspec-0.10.3-py3-none-any.whl (29 kB)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.8/dist-packages (from gradio==3.4.0->nemo_toolkit[all]) (2022.11.0)
# Collecting ffmpy
#   Downloading ffmpy-0.3.0.tar.gz (4.8 kB)
#   Preparing metadata (setup.py) ... done
# Collecting python-multipart
#   Downloading python-multipart-0.0.5.tar.gz (32 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pydantic in /usr/local/lib/python3.8/dist-packages (from gradio==3.4.0->nemo_toolkit[all]) (1.10.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from gradio==3.4.0->nemo_toolkit[all]) (2.25.1)
# Collecting fastapi
#   Downloading fastapi-0.89.1-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 KB 9.0 MB/s eta 0:00:00
# Collecting websockets
#   Downloading websockets-10.4-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.0/107.0 KB 17.0 MB/s eta 0:00:00
# Collecting orjson
#   Downloading orjson-3.8.5-cp38-cp38-manylinux_2_28_x86_64.whl (140 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 KB 21.3 MB/s eta 0:00:00
# Collecting markdown-it-py[linkify,plugins]
#   Downloading markdown_it_py-2.1.0-py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.5/84.5 KB 14.3 MB/s eta 0:00:00
# Collecting paramiko
#   Downloading paramiko-2.12.0-py2.py3-none-any.whl (213 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.1/213.1 KB 30.5 MB/s eta 0:00:00
# Collecting pycryptodome
#   Downloading pycryptodome-3.16.0-cp35-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (2.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 101.0 MB/s eta 0:00:00
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from gradio==3.4.0->nemo_toolkit[all]) (2.11.3)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.8/dist-packages (from gradio==3.4.0->nemo_toolkit[all]) (3.8.3)
# Requirement already satisfied: pillow in /usr/local/lib/python3.8/dist-packages (from gradio==3.4.0->nemo_toolkit[all]) (7.1.2)
# Collecting httpx
#   Downloading httpx-0.23.3-py3-none-any.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 KB 12.3 MB/s eta 0:00:00
# Collecting h11<0.13,>=0.11
#   Downloading h11-0.12.0-py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.9/54.9 KB 8.3 MB/s eta 0:00:00
# Collecting uvicorn
#   Downloading uvicorn-0.20.0-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.9/56.9 KB 6.8 MB/s eta 0:00:00
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.8/dist-packages (from hydra-core<1.3,>=1.2.0->nemo_toolkit[all]) (5.10.2)
# Collecting antlr4-python3-runtime==4.9.*
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 KB 18.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pipreqs
#   Downloading pipreqs-0.4.11-py2.py3-none-any.whl (32 kB)
# Collecting pip-api
#   Downloading pip_api-0.0.30-py3-none-any.whl (111 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.6/111.6 KB 15.3 MB/s eta 0:00:00
# Collecting levenshtein==0.20.2
#   Downloading Levenshtein-0.20.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 89.1 MB/s eta 0:00:00
# Requirement already satisfied: decorator>=4.0.10 in /usr/local/lib/python3.8/dist-packages (from librosa>=0.9.0->nemo_toolkit[all]) (4.4.2)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.8/dist-packages (from librosa>=0.9.0->nemo_toolkit[all]) (1.2.0)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.8/dist-packages (from librosa>=0.9.0->nemo_toolkit[all]) (3.0.0)
# Requirement already satisfied: resampy>=0.2.2 in /usr/local/lib/python3.8/dist-packages (from librosa>=0.9.0->nemo_toolkit[all]) (0.4.2)
# Requirement already satisfied: pooch>=1.0 in /usr/local/lib/python3.8/dist-packages (from librosa>=0.9.0->nemo_toolkit[all]) (1.6.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/dist-packages (from matplotlib->nemo_toolkit[all]) (0.11.0)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.38.0-py3-none-any.whl (965 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 965.4/965.4 KB 64.3 MB/s eta 0:00:00
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.0.7-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (300 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.0/300.0 KB 40.0 MB/s eta 0:00:00
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib->nemo_toolkit[all]) (1.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib->nemo_toolkit[all]) (3.0.9)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.8/dist-packages (from numba->nemo_toolkit[all]) (0.39.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.8/dist-packages (from numba->nemo_toolkit[all]) (6.0.0)
# Collecting numpy>=1.22
#   Downloading numpy-1.23.5-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 87.4 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=3.6.2.1 in /usr/local/lib/python3.8/dist-packages (from onnx>=1.7.0->nemo_toolkit[all]) (4.4.0)
# Collecting protobuf<4,>=3.20.2
#   Downloading protobuf-3.20.3-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 69.6 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil->nemo_toolkit[all]) (1.15.0)
# Collecting lightning-utilities!=0.4.0,>=0.3.0
#   Downloading lightning_utilities-0.5.0-py3-none-any.whl (18 kB)
# Collecting tensorboardX>=2.2
#   Downloading tensorboardX-2.5.1-py2.py3-none-any.whl (125 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.4/125.4 KB 20.2 MB/s eta 0:00:00
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn->nemo_toolkit[all]) (3.1.0)
# Collecting numpy>=1.22
#   Downloading numpy-1.22.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.9/16.9 MB 92.2 MB/s eta 0:00:00
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.8/dist-packages (from soundfile->nemo_toolkit[all]) (1.15.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from transformers<=4.21.2,>=4.0.1->nemo_toolkit[all]) (3.9.0)
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 116.0 MB/s eta 0:00:00
# Collecting botocore<1.30.0,>=1.29.51
#   Downloading botocore-1.29.51-py3-none-any.whl (10.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.3/10.3 MB 110.6 MB/s eta 0:00:00
# Collecting jmespath<2.0.0,>=0.7.1
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting s3transfer<0.7.0,>=0.6.0
#   Downloading s3transfer-0.6.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.6/79.6 KB 13.1 MB/s eta 0:00:00
# Collecting pybind11>=2.2
#   Using cached pybind11-2.10.3-py3-none-any.whl (222 kB)
# Collecting aniso8601>=0.82
#   Downloading aniso8601-9.0.1-py2.py3-none-any.whl (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 KB 8.4 MB/s eta 0:00:00
# Requirement already satisfied: pytz in /usr/local/lib/python3.8/dist-packages (from flask_restful->nemo_toolkit[all]) (2022.7)
# Requirement already satisfied: Flask>=0.8 in /usr/local/lib/python3.8/dist-packages (from flask_restful->nemo_toolkit[all]) (1.1.4)
# Requirement already satisfied: wcwidth>=0.2.5 in /usr/local/lib/python3.8/dist-packages (from ftfy->nemo_toolkit[all]) (0.2.5)
# Collecting distance>=0.1.3
#   Downloading Distance-0.1.3.tar.gz (180 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.3/180.3 KB 28.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.8/dist-packages (from gdown->nemo_toolkit[all]) (4.6.3)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.8/dist-packages (from ipywidgets->nemo_toolkit[all]) (5.3.4)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.8/dist-packages (from ipywidgets->nemo_toolkit[all]) (3.6.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.8/dist-packages (from ipywidgets->nemo_toolkit[all]) (0.2.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from ipywidgets->nemo_toolkit[all]) (3.0.5)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.8/dist-packages (from ipywidgets->nemo_toolkit[all]) (5.7.1)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.8/dist-packages (from ipywidgets->nemo_toolkit[all]) (7.9.0)
# Requirement already satisfied: sortedcontainers>=2.0.4 in /usr/local/lib/python3.8/dist-packages (from pyannote.core->nemo_toolkit[all]) (2.4.0)
# Requirement already satisfied: sympy>=1.1 in /usr/local/lib/python3.8/dist-packages (from pyannote.metrics->nemo_toolkit[all]) (1.7.1)
# Collecting docopt>=0.6.2
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Collecting pyannote.database>=4.0.1
#   Downloading pyannote.database-4.1.3-py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.6/41.6 KB 4.5 MB/s eta 0:00:00
# Requirement already satisfied: more-itertools>=4.0.0 in /usr/local/lib/python3.8/dist-packages (from pytest->nemo_toolkit[all]) (9.0.0)
# Requirement already satisfied: atomicwrites>=1.0 in /usr/local/lib/python3.8/dist-packages (from pytest->nemo_toolkit[all]) (1.4.1)
# Requirement already satisfied: pluggy<0.8,>=0.5 in /usr/local/lib/python3.8/dist-packages (from pytest->nemo_toolkit[all]) (0.7.1)
# Requirement already satisfied: py>=1.5.0 in /usr/local/lib/python3.8/dist-packages (from pytest->nemo_toolkit[all]) (1.11.0)
# Collecting ruamel.yaml.clib>=0.2.6
#   Downloading ruamel.yaml.clib-0.2.7-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (555 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 555.3/555.3 KB 53.2 MB/s eta 0:00:00
# Collecting colorama
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Collecting portalocker
#   Downloading portalocker-2.6.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.8/dist-packages (from sacrebleu[ja]->nemo_toolkit[all]) (4.9.2)
# Collecting mecab-python3==1.0.5
#   Downloading mecab_python3-1.0.5-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (577 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 577.3/577.3 KB 61.5 MB/s eta 0:00:00
# Collecting ipadic<2.0,>=1.0
#   Downloading ipadic-1.0.0.tar.gz (13.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.4/13.4 MB 92.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torchvision in /usr/local/lib/python3.8/dist-packages (from sentence_transformers->nemo_toolkit[all]) (0.14.1+cu116)
# Requirement already satisfied: sphinxcontrib-applehelp in /usr/local/lib/python3.8/dist-packages (from sphinx->nemo_toolkit[all]) (1.0.3)
# Requirement already satisfied: sphinxcontrib-serializinghtml in /usr/local/lib/python3.8/dist-packages (from sphinx->nemo_toolkit[all]) (1.1.5)
# Requirement already satisfied: sphinxcontrib-devhelp in /usr/local/lib/python3.8/dist-packages (from sphinx->nemo_toolkit[all]) (1.0.2)
# Requirement already satisfied: Pygments>=2.0 in /usr/local/lib/python3.8/dist-packages (from sphinx->nemo_toolkit[all]) (2.6.1)
# Requirement already satisfied: snowballstemmer>=1.1 in /usr/local/lib/python3.8/dist-packages (from sphinx->nemo_toolkit[all]) (2.2.0)
# Requirement already satisfied: babel>=1.3 in /usr/local/lib/python3.8/dist-packages (from sphinx->nemo_toolkit[all]) (2.11.0)
# Requirement already satisfied: sphinxcontrib-jsmath in /usr/local/lib/python3.8/dist-packages (from sphinx->nemo_toolkit[all]) (1.0.1)
# Requirement already satisfied: imagesize in /usr/local/lib/python3.8/dist-packages (from sphinx->nemo_toolkit[all]) (1.4.1)
# Requirement already satisfied: alabaster<0.8,>=0.7 in /usr/local/lib/python3.8/dist-packages (from sphinx->nemo_toolkit[all]) (0.7.12)
# Requirement already satisfied: docutils<0.17,>=0.12 in /usr/local/lib/python3.8/dist-packages (from sphinx->nemo_toolkit[all]) (0.16)
# Requirement already satisfied: sphinxcontrib-qthelp in /usr/local/lib/python3.8/dist-packages (from sphinx->nemo_toolkit[all]) (1.0.3)
# Requirement already satisfied: sphinxcontrib-htmlhelp in /usr/local/lib/python3.8/dist-packages (from sphinx->nemo_toolkit[all]) (2.0.0)
# Collecting pybtex-docutils>=1.0.0
#   Downloading pybtex_docutils-1.0.2-py3-none-any.whl (6.3 kB)
# Collecting pybtex>=0.24
#   Downloading pybtex-0.24.0-py2.py3-none-any.whl (561 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 561.4/561.4 KB 58.1 MB/s eta 0:00:00
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.8/dist-packages (from tensorboard->nemo_toolkit[all]) (2.16.0)
# Collecting tensorboard
#   Downloading tensorboard-2.11.2-py3-none-any.whl (6.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 116.1 MB/s eta 0:00:00
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard->nemo_toolkit[all]) (1.0.1)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.8/dist-packages (from tensorboard->nemo_toolkit[all]) (1.51.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard->nemo_toolkit[all]) (1.8.1)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.8/dist-packages (from tensorboard->nemo_toolkit[all]) (1.3.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.8/dist-packages (from tensorboard->nemo_toolkit[all]) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard->nemo_toolkit[all]) (0.6.1)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.8/dist-packages (from tensorboard->nemo_toolkit[all]) (0.38.4)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard->nemo_toolkit[all]) (0.4.6)
# Collecting loguru
#   Downloading loguru-0.6.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 KB 9.2 MB/s eta 0:00:00
# Collecting plac
#   Downloading plac-1.3.5-py2.py3-none-any.whl (22 kB)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.8/dist-packages (from texterrors->nemo_toolkit[all]) (2.2.0)
# Collecting setproctitle
#   Downloading setproctitle-1.3.2-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (31 kB)
# Collecting pathtools
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Collecting GitPython>=1.0.0
#   Downloading GitPython-3.1.30-py3-none-any.whl (184 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.0/184.0 KB 25.9 MB/s eta 0:00:00
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.8/dist-packages (from wandb->nemo_toolkit[all]) (5.4.8)
# Collecting sentry-sdk>=1.0.0
#   Downloading sentry_sdk-1.13.0-py2.py3-none-any.whl (177 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.4/177.4 KB 25.8 MB/s eta 0:00:00
# Collecting docker-pycreds>=0.4.0
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Collecting urllib3<1.27,>=1.25.4
#   Downloading urllib3-1.26.14-py2.py3-none-any.whl (140 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 KB 21.6 MB/s eta 0:00:00
# Requirement already satisfied: pycparser in /usr/local/lib/python3.8/dist-packages (from cffi>=1.0->soundfile->nemo_toolkit[all]) (2.21)
# Requirement already satisfied: itsdangerous<2.0,>=0.24 in /usr/local/lib/python3.8/dist-packages (from Flask>=0.8->flask_restful->nemo_toolkit[all]) (1.1.0)
# Collecting Flask>=0.8
#   Downloading Flask-2.2.2-py3-none-any.whl (101 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.5/101.5 KB 14.9 MB/s eta 0:00:00
# Collecting werkzeug>=1.0.1
#   Downloading Werkzeug-2.2.2-py3-none-any.whl (232 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.7/232.7 KB 33.5 MB/s eta 0:00:00
# Collecting itsdangerous>=2.0
#   Downloading itsdangerous-2.1.2-py3-none-any.whl (15 kB)
# Collecting jinja2
#   Downloading Jinja2-3.1.2-py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.1/133.1 KB 20.4 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->gradio==3.4.0->nemo_toolkit[all]) (2.1.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.8/dist-packages (from aiohttp->gradio==3.4.0->nemo_toolkit[all]) (6.0.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.8/dist-packages (from aiohttp->gradio==3.4.0->nemo_toolkit[all]) (1.3.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->gradio==3.4.0->nemo_toolkit[all]) (1.8.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.8/dist-packages (from aiohttp->gradio==3.4.0->nemo_toolkit[all]) (1.3.3)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.8/dist-packages (from aiohttp->gradio==3.4.0->nemo_toolkit[all]) (4.0.2)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 KB 9.8 MB/s eta 0:00:00
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard->nemo_toolkit[all]) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard->nemo_toolkit[all]) (5.2.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard->nemo_toolkit[all]) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.8/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard->nemo_toolkit[all]) (1.3.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata->numba->nemo_toolkit[all]) (3.11.0)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.8/dist-packages (from ipykernel>=4.5.1->ipywidgets->nemo_toolkit[all]) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.8/dist-packages (from ipykernel>=4.5.1->ipywidgets->nemo_toolkit[all]) (6.0.4)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from ipython>=4.0.0->ipywidgets->nemo_toolkit[all]) (2.0.10)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.8/dist-packages (from ipython>=4.0.0->ipywidgets->nemo_toolkit[all]) (0.7.5)
# Collecting jedi>=0.10
#   Downloading jedi-0.18.2-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 80.5 MB/s eta 0:00:00
# Requirement already satisfied: backcall in /usr/local/lib/python3.8/dist-packages (from ipython>=4.0.0->ipywidgets->nemo_toolkit[all]) (0.2.0)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.8/dist-packages (from ipython>=4.0.0->ipywidgets->nemo_toolkit[all]) (4.8.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.8/dist-packages (from jinja2->gradio==3.4.0->nemo_toolkit[all]) (2.0.1)
# Requirement already satisfied: typer[all]>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from pyannote.database>=4.0.1->pyannote.metrics->nemo_toolkit[all]) (0.7.0)
# Collecting latexcodec>=1.0.4
#   Downloading latexcodec-2.0.1-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->gradio==3.4.0->nemo_toolkit[all]) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->gradio==3.4.0->nemo_toolkit[all]) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->gradio==3.4.0->nemo_toolkit[all]) (2022.12.7)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.8/dist-packages (from sympy>=1.1->pyannote.metrics->nemo_toolkit[all]) (1.2.1)
# Collecting tensorboardX>=2.2
#   Downloading tensorboardX-2.5-py2.py3-none-any.whl (125 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.3/125.3 KB 18.9 MB/s eta 0:00:00
# Collecting MarkupSafe>=2.0
#   Downloading MarkupSafe-2.1.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.8/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (5.7.16)
# Collecting starlette==0.22.0
#   Downloading starlette-0.22.0-py3-none-any.whl (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.3/64.3 KB 10.4 MB/s eta 0:00:00
# Collecting anyio<5,>=3.4.0
#   Downloading anyio-3.6.2-py3-none-any.whl (80 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.6/80.6 KB 13.3 MB/s eta 0:00:00
# Collecting httpcore<0.17.0,>=0.15.0
#   Downloading httpcore-0.16.3-py3-none-any.whl (69 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.6/69.6 KB 10.6 MB/s eta 0:00:00
# Collecting sniffio
#   Downloading sniffio-1.3.0-py3-none-any.whl (10 kB)
# Collecting rfc3986[idna2008]<2,>=1.3
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Collecting mdit-py-plugins
#   Downloading mdit_py_plugins-0.3.3-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.5/50.5 KB 8.2 MB/s eta 0:00:00
# Collecting linkify-it-py~=1.0
#   Downloading linkify_it_py-1.0.3-py3-none-any.whl (19 kB)
# Collecting bcrypt>=3.1.3
#   Downloading bcrypt-4.0.1-cp36-abi3-manylinux_2_28_x86_64.whl (593 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 593.7/593.7 KB 62.5 MB/s eta 0:00:00
# Collecting cryptography>=2.5
#   Downloading cryptography-39.0.0-cp36-abi3-manylinux_2_28_x86_64.whl (4.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 76.7 MB/s eta 0:00:00
# Collecting pynacl>=1.0.1
#   Downloading PyNaCl-1.5.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (856 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 856.7/856.7 KB 72.1 MB/s eta 0:00:00
# Requirement already satisfied: pip in /usr/local/lib/python3.8/dist-packages (from pip-api->isort[requirements]<5->nemo_toolkit[all]) (22.0.4)
# Collecting yarg
#   Downloading yarg-0.1.9-py2.py3-none-any.whl (19 kB)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.8/dist-packages (from requests->gradio==3.4.0->nemo_toolkit[all]) (1.7.1)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Collecting httpcore<0.17.0,>=0.15.0
#   Downloading httpcore-0.16.2-py3-none-any.whl (68 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.0/69.0 KB 11.5 MB/s eta 0:00:00
#   Downloading httpcore-0.16.1-py3-none-any.whl (68 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.7/68.7 KB 11.5 MB/s eta 0:00:00
#   Downloading httpcore-0.16.0-py3-none-any.whl (68 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.7/68.7 KB 11.3 MB/s eta 0:00:00
#   Downloading httpcore-0.15.0-py3-none-any.whl (68 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.4/68.4 KB 11.6 MB/s eta 0:00:00
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.8/dist-packages (from jedi>=0.10->ipython>=4.0.0->ipywidgets->nemo_toolkit[all]) (0.8.3)
# Collecting uc-micro-py
#   Downloading uc_micro_py-1.0.1-py3-none-any.whl (6.2 kB)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (1.8.0)
# Collecting jinja2
#   Downloading Jinja2-3.0.0-py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 KB 14.1 MB/s eta 0:00:00
# Requirement already satisfied: terminado>=0.8.1 in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (0.13.3)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (0.15.0)
# Requirement already satisfied: nbconvert<6.0 in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (5.6.1)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (5.7.1)
# Requirement already satisfied: jupyter-core>=4.4.0 in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (5.1.3)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.8/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (23.2.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.8/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->nemo_toolkit[all]) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.8/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard->nemo_toolkit[all]) (3.2.2)
# Collecting shellingham<2.0.0,>=1.3.0
#   Downloading shellingham-1.5.0.post1-py2.py3-none-any.whl (9.4 kB)
# Collecting rich<13.0.0,>=10.11.0
#   Downloading rich-12.6.0-py3-none-any.whl (237 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 237.5/237.5 KB 32.8 MB/s eta 0:00:00
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.8/dist-packages (from pexpect->ipython>=4.0.0->ipywidgets->nemo_toolkit[all]) (0.7.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.8/dist-packages (from jupyter-core>=4.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (2.6.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.8/dist-packages (from nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (0.8.4)
# Requirement already satisfied: testpath in /usr/local/lib/python3.8/dist-packages (from nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (0.6.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.8/dist-packages (from nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (1.5.0)
# Requirement already satisfied: bleach in /usr/local/lib/python3.8/dist-packages (from nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (5.0.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.8/dist-packages (from nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (0.4)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.8/dist-packages (from nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (0.7.1)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.8/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.8/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (4.3.3)
# Collecting commonmark<0.10.0,>=0.9.0
#   Downloading commonmark-0.9.1-py2.py3-none-any.whl (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.1/51.1 KB 6.3 MB/s eta 0:00:00
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (0.19.3)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.8/dist-packages (from bleach->nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (0.5.1)
# Building wheels for collected packages: antlr4-python3-runtime, progress, sacremoses, fasttext, kaldi-python-io, kaldiio, nemo_toolkit, sentence_transformers, distance, docopt, ipadic, ffmpy, pathtools, python-multipart
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144575 sha256=03aeb810c5304f60e34ab20c55919b58db8125d2896f71c5ad56faf65a9432aa
#   Stored in directory: /root/.cache/pip/wheels/b1/a3/c2/6df046c09459b73cc9bb6c4401b0be6c47048baf9a1617c485
#   Building wheel for progress (setup.py) ... done
#   Created wheel for progress: filename=progress-1.6-py3-none-any.whl size=9630 sha256=0ceef0bd13ab34f6a2a901bec12e0a8c311dd0c5b0edd91e81e462a6d8305e3c
#   Stored in directory: /root/.cache/pip/wheels/bb/01/5a/c916509df9b12c6465864251dbe826def8e31a16fa7da54f08
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.53-py3-none-any.whl size=895260 sha256=174af7ce4f9e2fcb7aa153683ac50c50062369c99a069b7445dee8649737e546
#   Stored in directory: /root/.cache/pip/wheels/82/ab/9b/c15899bf659ba74f623ac776e861cf2eb8608c1825ddec66a4
#   Building wheel for fasttext (setup.py) ... done
#   Created wheel for fasttext: filename=fasttext-0.9.2-cp38-cp38-linux_x86_64.whl size=4400570 sha256=288eac8e28e76a1674c24a4cd8c0b64a2c83c26987e0e2727850da1f67a22feb
#   Stored in directory: /root/.cache/pip/wheels/93/61/2a/c54711a91c418ba06ba195b1d78ff24fcaad8592f2a694ac94
#   Building wheel for kaldi-python-io (setup.py) ... done
#   Created wheel for kaldi-python-io: filename=kaldi_python_io-1.2.2-py3-none-any.whl size=8970 sha256=d6937ab520f22bd7d37ce27dc2c723909ae11a5dc22e33e03da8cbb28c38f69a
#   Stored in directory: /root/.cache/pip/wheels/8c/da/46/4afb7e26376c33af41c3ec388d5b63d34d186f6df1545cac30
#   Building wheel for kaldiio (setup.py) ... done
#   Created wheel for kaldiio: filename=kaldiio-2.17.2-py3-none-any.whl size=24471 sha256=8c9ac3cdecd8772856869bf20bda77b34299afad2d9ed5252e318439afa5cee9
#   Stored in directory: /root/.cache/pip/wheels/49/b3/00/af2103b510836161326bb51e27795407b07fda6969d0ae5967
#   Building wheel for nemo_toolkit (setup.py) ... done
#   Created wheel for nemo_toolkit: filename=nemo_toolkit-1.15.0rc0-py3-none-any.whl size=4366834 sha256=940331e231c5bbcec1294d8b80374805e727d682b1496c3af3dd4ee175199812
#   Stored in directory: /tmp/pip-ephem-wheel-cache-25y1w8xe/wheels/76/8c/14/f1ad178881c7340cf8e629686593904531249cf8b2de155d8c
#   Building wheel for sentence_transformers (setup.py) ... done
#   Created wheel for sentence_transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125938 sha256=8c0cdb5f3000cdf36517f869808b94a04496ace5897c2fb35708ab1e770a1b53
#   Stored in directory: /root/.cache/pip/wheels/5e/6f/8c/d88aec621f3f542d26fac0342bef5e693335d125f4e54aeffe
#   Building wheel for distance (setup.py) ... done
#   Created wheel for distance: filename=Distance-0.1.3-py3-none-any.whl size=16275 sha256=db5558259c9d0a4eb2e3409f455d0a5d42072cdd063086000390a2753c8e1240
#   Stored in directory: /root/.cache/pip/wheels/fb/a8/64/6edcab63ec51512a87cacf9b3563c711ad6b7b05d61b704493
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13723 sha256=947cde251968ec435148ed49242f6c370ba4300c5f031c5557717cef6f27a57b
#   Stored in directory: /root/.cache/pip/wheels/56/ea/58/ead137b087d9e326852a851351d1debf4ada529b6ac0ec4e8c
#   Building wheel for ipadic (setup.py) ... done
#   Created wheel for ipadic: filename=ipadic-1.0.0-py3-none-any.whl size=13556723 sha256=8c32a4b54fcecc67e7589ea3dbaed33f52f8ce5c8f2808ffa67278f69b958037
#   Stored in directory: /root/.cache/pip/wheels/45/b7/f5/a21e68db846eedcd00d69e37d60bab3f68eb20b1d99cdff652
#   Building wheel for ffmpy (setup.py) ... done
#   Created wheel for ffmpy: filename=ffmpy-0.3.0-py3-none-any.whl size=4711 sha256=10e44c675e0e0b83f353b21fe6c006647fae40e9c1a230ec0d97de290e963d2d
#   Stored in directory: /root/.cache/pip/wheels/ff/5b/59/913b443e7369dc04b61f607a746b6f7d83fb65e2e19fcc958d
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8806 sha256=ac9f383bfd3fa995a75f44691b7b70cbf3ccb74f0f313c465e7d5d4f6993ccdd
#   Stored in directory: /root/.cache/pip/wheels/4c/8e/7e/72fbc243e1aeecae64a96875432e70d4e92f3d2d18123be004
#   Building wheel for python-multipart (setup.py) ... done
#   Created wheel for python-multipart: filename=python_multipart-0.0.5-py3-none-any.whl size=31678 sha256=e2b8de2a1b03a35f8790904b7d0ecbdb0af2ed11f08f852a1f194406bd84f14d
#   Stored in directory: /root/.cache/pip/wheels/9e/fc/1c/cf980e6413d3ee8e70cd8f39e2366b0f487e3e221aeb452eb0
# Successfully built antlr4-python3-runtime progress sacremoses fasttext kaldi-python-io kaldiio nemo_toolkit sentence_transformers distance docopt ipadic ffmpy pathtools python-multipart
# Installing collected packages: tokenizers, sentencepiece, rfc3986, pydub, progress, plac, pathtools, parameterized, pangu, opencc, mecab-python3, ipadic, ijson, ffmpy, faiss-cpu, docopt, distance, commonmark, braceexpand, antlr4-python3-runtime, aniso8601, websockets, urllib3, uc-micro-py, typed-ast, textdistance, sniffio, smmap, shellingham, setuptools, setproctitle, ruamel.yaml.clib, rich, rapidfuzz, pyyaml, python-multipart, pytest-runner, pypinyin, pycryptodome, pybind11, protobuf, portalocker, pip-api, pathspec, orjson, numpy, mdurl, MarkupSafe, loguru, latexcodec, jmespath, jedi, itsdangerous, isort, h11, ftfy, fonttools, einops, docker-pycreds, colorama, click, bcrypt, attrdict, youtokentome, werkzeug, webdataset, uvicorn, torchmetrics, tensorboardX, sox, sentry-sdk, sacremoses, sacrebleu, ruamel.yaml, pypinyin-dict, pynacl, pybtex, onnx, omegaconf, markdown-it-py, linkify-it-py, lightning-utilities, levenshtein, kaldiio, kaldi-python-io, jinja2, gitdb, fasttext, cryptography, contourpy, botocore, black, anyio, yarg, texterrors, starlette, s3transfer, pybtex-docutils, pyannote.core, paramiko, mdit-py-plugins, matplotlib, jiwer, hydra-core, huggingface_hub, httpcore, GitPython, g2p_en, Flask, wandb, transformers, sphinxcontrib-bibtex, pytorch-lightning, pyannote.database, pipreqs, librosa, httpx, flask_restful, fastapi, boto3, tensorboard, sentence_transformers, pyannote.metrics, gradio, nemo_toolkit
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 57.4.0
#     Uninstalling setuptools-57.4.0:
#       Successfully uninstalled setuptools-57.4.0
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 6.0
#     Uninstalling PyYAML-6.0:
#       Successfully uninstalled PyYAML-6.0
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.19.6
#     Uninstalling protobuf-3.19.6:
#       Successfully uninstalled protobuf-3.19.6
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.6
#     Uninstalling numpy-1.21.6:
#       Successfully uninstalled numpy-1.21.6
#   Attempting uninstall: MarkupSafe
#     Found existing installation: MarkupSafe 2.0.1
#     Uninstalling MarkupSafe-2.0.1:
#       Successfully uninstalled MarkupSafe-2.0.1
#   Attempting uninstall: itsdangerous
#     Found existing installation: itsdangerous 1.1.0
#     Uninstalling itsdangerous-1.1.0:
#       Successfully uninstalled itsdangerous-1.1.0
#   Attempting uninstall: click
#     Found existing installation: click 7.1.2
#     Uninstalling click-7.1.2:
#       Successfully uninstalled click-7.1.2
#   Attempting uninstall: werkzeug
#     Found existing installation: Werkzeug 1.0.1
#     Uninstalling Werkzeug-1.0.1:
#       Successfully uninstalled Werkzeug-1.0.1
#   Attempting uninstall: jinja2
#     Found existing installation: Jinja2 2.11.3
#     Uninstalling Jinja2-2.11.3:
#       Successfully uninstalled Jinja2-2.11.3
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.2.2
#     Uninstalling matplotlib-3.2.2:
#       Successfully uninstalled matplotlib-3.2.2
#   Attempting uninstall: Flask
#     Found existing installation: Flask 1.1.4
#     Uninstalling Flask-1.1.4:
#       Successfully uninstalled Flask-1.1.4
#   Attempting uninstall: librosa
#     Found existing installation: librosa 0.8.1
#     Uninstalling librosa-0.8.1:
#       Successfully uninstalled librosa-0.8.1
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.9.1
#     Uninstalling tensorboard-2.9.1:
#       Successfully uninstalled tensorboard-2.9.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.9.2 requires protobuf<3.20,>=3.9.2, but you have protobuf 3.20.3 which is incompatible.
# tensorflow 2.9.2 requires tensorboard<2.10,>=2.9, but you have tensorboard 2.11.2 which is incompatible.
# Successfully installed Flask-2.2.2 GitPython-3.1.30 MarkupSafe-2.1.2 aniso8601-9.0.1 antlr4-python3-runtime-4.9.3 anyio-3.6.2 attrdict-2.0.1 bcrypt-4.0.1 black-19.10b0 boto3-1.26.51 botocore-1.29.51 braceexpand-0.1.7 click-8.0.2 colorama-0.4.6 commonmark-0.9.1 contourpy-1.0.7 cryptography-39.0.0 distance-0.1.3 docker-pycreds-0.4.0 docopt-0.6.2 einops-0.6.0 faiss-cpu-1.7.3 fastapi-0.89.1 fasttext-0.9.2 ffmpy-0.3.0 flask_restful-0.3.9 fonttools-4.38.0 ftfy-6.1.1 g2p_en-2.1.0 gitdb-4.0.10 gradio-3.4.0 h11-0.12.0 httpcore-0.15.0 httpx-0.23.3 huggingface_hub-0.11.1 hydra-core-1.2.0 ijson-3.2.0.post0 ipadic-1.0.0 isort-4.3.21 itsdangerous-2.1.2 jedi-0.18.2 jinja2-3.0.0 jiwer-2.5.1 jmespath-1.0.1 kaldi-python-io-1.2.2 kaldiio-2.17.2 latexcodec-2.0.1 levenshtein-0.20.2 librosa-0.9.2 lightning-utilities-0.5.0 linkify-it-py-1.0.3 loguru-0.6.0 markdown-it-py-2.1.0 matplotlib-3.6.3 mdit-py-plugins-0.3.3 mdurl-0.1.2 mecab-python3-1.0.5 nemo_toolkit-1.15.0rc0 numpy-1.22.4 omegaconf-2.2.3 onnx-1.13.0 opencc-1.1.6 orjson-3.8.5 pangu-4.0.6.1 parameterized-0.8.1 paramiko-2.12.0 pathspec-0.10.3 pathtools-0.1.2 pip-api-0.0.30 pipreqs-0.4.11 plac-1.3.5 portalocker-2.6.0 progress-1.6 protobuf-3.20.3 pyannote.core-5.0.0 pyannote.database-4.1.3 pyannote.metrics-3.2.1 pybind11-2.10.3 pybtex-0.24.0 pybtex-docutils-1.0.2 pycryptodome-3.16.0 pydub-0.25.1 pynacl-1.5.0 pypinyin-0.48.0 pypinyin-dict-0.5.0 pytest-runner-6.0.0 python-multipart-0.0.5 pytorch-lightning-1.8.6 pyyaml-5.4.1 rapidfuzz-2.13.7 rfc3986-1.5.0 rich-12.6.0 ruamel.yaml-0.17.21 ruamel.yaml.clib-0.2.7 s3transfer-0.6.0 sacrebleu-2.3.1 sacremoses-0.0.53 sentence_transformers-2.2.2 sentencepiece-0.1.97 sentry-sdk-1.13.0 setproctitle-1.3.2 setuptools-59.5.0 shellingham-1.5.0.post1 smmap-5.0.0 sniffio-1.3.0 sox-1.4.1 sphinxcontrib-bibtex-2.5.0 starlette-0.22.0 tensorboard-2.11.2 tensorboardX-2.5 textdistance-4.5.0 texterrors-0.4.4 tokenizers-0.12.1 torchmetrics-0.11.0 transformers-4.21.2 typed-ast-1.5.4 uc-micro-py-1.0.1 urllib3-1.26.14 uvicorn-0.20.0 wandb-0.13.9 webdataset-0.1.62 websockets-10.4 werkzeug-2.2.2 yarg-0.1.9 youtokentome-1.0.6
# '\nRemember to restart the runtime for the kernel to pick up any upgraded packages (e.g. matplotlib)!\nAlternatively, you can uncomment the exit() below to crash and restart the kernel, in the case\nthat you want to use the "Run All Cells" (or similar) option.\n'

# %% [markdown]
# ---
# ## Fine-tuning ASR model using NeMo

# %% [markdown]
# ### Download Data

# %% [markdown]
# In this tutorial we will use the popular AN4 dataset. Let's download it.

# %%
! wget https://dldata-public.s3.us-east-2.amazonaws.com/an4_sphere.tar.gz  # for the original source, please visit http://www.speech.cs.cmu.edu/databases/an4/an4_sphere.tar.gz
# Out:
# --2023-01-18 18:47:05--  https://dldata-public.s3.us-east-2.amazonaws.com/an4_sphere.tar.gz
# Resolving dldata-public.s3.us-east-2.amazonaws.com (dldata-public.s3.us-east-2.amazonaws.com)... 52.219.92.114
# Connecting to dldata-public.s3.us-east-2.amazonaws.com (dldata-public.s3.us-east-2.amazonaws.com)|52.219.92.114|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 64327561 (61M) [application/x-gzip]
# Saving to: ‘an4_sphere.tar.gz’
#
# an4_sphere.tar.gz   100%[===================>]  61.35M  22.7MB/s    in 2.7s
#
# 2023-01-18 18:47:08 (22.7 MB/s) - ‘an4_sphere.tar.gz’ saved [64327561/64327561]

# %% [markdown]
# After downloading, untar the dataset and move it to the correct directory.

# %%
import os
DATA_DIR = os.getcwd()
os.environ["DATA_DIR"] = DATA_DIR
! tar -xvf an4_sphere.tar.gz 
! mv an4 $DATA_DIR
# Out:
# env: DATA_DIR=.
# an4/
# an4/README
# an4/etc/
# an4/etc/an4_test.fileids
# an4/etc/an4.ug.lm
# an4/etc/an4.ug.lm.DMP
# an4/etc/an4_train.fileids
# an4/etc/an4_train.transcription
# an4/etc/an4_test.transcription
# an4/etc/an4.dic
# an4/etc/an4.phone
# an4/etc/an4.filler
# an4/wav/
# an4/wav/an4test_clstk/mjgm/cen6-mjgm-b.sph
# an4/wav/an4test_clstk/mjgm/cen7-mjgm-b.sph
# an4/wav/an4test_clstk/mjgm/cen8-mjgm-b.sph
# an4/wav/an4test_clstk/mjwl/
# an4/wav/an4test_clstk/mjwl/an391-mjwl-b.sph
# an4/wav/an4test_clstk/mjwl/an392-mjwl-b.sph
# an4/wav/an4test_clstk/mjwl/an393-mjwl-b.sph
# an4/wav/an4test_clstk/mjwl/an394-mjwl-b.sph
# an4/wav/an4test_clstk/mjwl/an395-mjwl-b.sph
# an4/wav/an4test_clstk/mjwl/cen1-mjwl-b.sph
# an4/wav/an4test_clstk/mjwl/cen2-mjwl-b.sph
# an4/wav/an4test_clstk/mjwl/cen3-mjwl-b.sph
# an4/wav/an4test_clstk/mjwl/cen4-mjwl-b.sph
# an4/wav/an4test_clstk/mjwl/cen5-mjwl-b.sph
# an4/wav/an4test_clstk/mjwl/cen6-mjwl-b.sph
# an4/wav/an4test_clstk/mjwl/cen7-mjwl-b.sph
# an4/wav/an4test_clstk/mjwl/cen8-mjwl-b.sph
# an4/wav/an4test_clstk/mmxg/
# an4/wav/an4test_clstk/mmxg/an441-mmxg-b.sph
# an4/wav/an4test_clstk/mmxg/an442-mmxg-b.sph
# an4/wav/an4test_clstk/mmxg/an443-mmxg-b.sph
# an4/wav/an4test_clstk/mmxg/an444-mmxg-b.sph
# an4/wav/an4test_clstk/mmxg/an445-mmxg-b.sph
# an4/wav/an4test_clstk/mmxg/cen1-mmxg-b.sph
# an4/wav/an4test_clstk/mmxg/cen2-mmxg-b.sph
# an4/wav/an4test_clstk/mmxg/cen3-mmxg-b.sph
# an4/wav/an4test_clstk/mmxg/cen4-mmxg-b.sph
# an4/wav/an4test_clstk/mmxg/cen5-mmxg-b.sph
# an4/wav/an4test_clstk/mmxg/cen6-mmxg-b.sph
# an4/wav/an4test_clstk/mmxg/cen7-mmxg-b.sph
# an4/wav/an4test_clstk/mmxg/cen8-mmxg-b.sph
# an4/LICENSE
# mv: 'an4' and './an4' are the same file

# %% [markdown]
# ### Pre-Processing

# %% [markdown]
# This step converts the `.mp3` files into `.wav` files and splits the data into training and testing sets. It also generates a "meta-data" file to be consumed by the data-loader for training and testing.

# %%
import json, librosa, os, glob
import subprocess


source_data_dir = f"{DATA_DIR}/an4"
target_data_dir = f"{DATA_DIR}/an4_converted"

def an4_build_manifest(transcripts_path, manifest_path, target_wavs_dir):
    """Build an AN4 manifest from a given transcript file."""
    with open(transcripts_path, 'r') as fin:
        with open(manifest_path, 'w') as fout:
            for line in fin:
                # Lines look like this:
                # <s> transcript </s> (fileID)
                transcript = line[: line.find('(') - 1].lower()
                transcript = transcript.replace('<s>', '').replace('</s>', '')
                transcript = transcript.strip()

                file_id = line[line.find('(') + 1 : -2]  # e.g. "cen4-fash-b"
                audio_path = os.path.join(target_wavs_dir, file_id + '.wav')

                duration = librosa.core.get_duration(filename=audio_path)

                # Write the metadata to the manifest
                metadata = {"audio_filepath": audio_path, "duration": duration, "text": transcript}
                json.dump(metadata, fout)
                fout.write('\n')

"""Process AN4 dataset."""
if not os.path.exists(source_data_dir):
    link = 'http://www.speech.cs.cmu.edu/databases/an4/an4_sphere.tar.gz'
    raise ValueError(
        f"Data not found at `{source_data_dir}`. Please download the AN4 dataset from `{link}` "
        f"and extract it into the folder specified by the `source_data_dir` argument."
    )

# Conversion from SPH files to WAV files
sph_list = glob.glob(os.path.join(source_data_dir, '**/*.sph'), recursive=True)
target_wavs_dir = os.path.join(target_data_dir, 'wavs')
if not os.path.exists(target_wavs_dir):
    print(f"Creating directories for {target_wavs_dir}.")
    os.makedirs(os.path.join(target_data_dir, 'wavs'))

for sph_path in sph_list:
    wav_path = os.path.join(target_wavs_dir, os.path.splitext(os.path.basename(sph_path))[0] + '.wav')
    cmd = ["sox", sph_path, wav_path]
    subprocess.run(cmd, check=True)

# Build AN4 manifests
train_transcripts = os.path.join(source_data_dir, 'etc/an4_train.transcription')
train_manifest = os.path.join(target_data_dir, 'train_manifest.json')
an4_build_manifest(train_transcripts, train_manifest, target_wavs_dir)

test_transcripts = os.path.join(source_data_dir, 'etc/an4_test.transcription')
test_manifest = os.path.join(target_data_dir, 'test_manifest.json')
an4_build_manifest(test_transcripts, test_manifest, target_wavs_dir)
# Out:
# Creating directories for ./an4_converted/wavs.

# %% [markdown]
# Let's listen to a sample audio file.

# %%
# change path of the file here
import os
import IPython.display as ipd
path = os.environ["DATA_DIR"] + '/an4_converted/wavs/an268-mbmg-b.wav'
ipd.Audio(path)

# %% [markdown]
# ### Training

# %% [markdown]
# #### Create Tokenizer

# %% [markdown]
# Before we can do the actual training, we need to create a tokenizer as this ASR model uses word-piece encoding. Character based models don't need the tokenizer creation as only single characters are regarded as elements in the vocabulary in their cases. We can use the `process_asr_text_tokenizer.py` script of NeMo to create the tokenizer that generates the subword vocabulary for us for use in training. The size of the vocabulary (vocab_size) should be the same as the vocabulary size as the ASR model. We would clone the NeMo's repository from GitHub to use the scripts and examples available there.

# %%
# clone NeMo locally
NEMO_DIR = 'FIX_ME/path/to/NeMo'
! git clone https://github.com/NVIDIA/NeMo $NEMO_DIR

# create the tokenizer
# !python $NEMO_DIR/scripts/tokenizers/process_asr_text_tokenizer.py \
         --manifest=$DATA_DIR/an4_converted/train_manifest.json \
         --data_root=$DATA_DIR/an4 \
         --vocab_size=128 \
         --tokenizer=spe \
         --spe_type=unigram
# Out:
# Cloning into 'NeMo'...
# remote: Enumerating objects: 139107, done.
# remote: Counting objects: 100% (234/234), done.
# remote: Compressing objects: 100% (127/127), done.
# remote: Total 139107 (delta 117), reused 184 (delta 107), pack-reused 138873
# Receiving objects: 100% (139107/139107), 370.82 MiB | 23.27 MiB/s, done.
# Resolving deltas: 100% (106276/106276), done.
# [NeMo W 2023-01-18 18:47:52 optimizers:55] Apex was not found. Using the lamb or fused_adam optimizer will error out.
# [NeMo I 2023-01-18 18:47:52 sentencepiece_tokenizer:315] Processing ./an4/text_corpus/document.txt and store at ./an4/tokenizer_spe_unigram_v128
# sentencepiece_trainer.cc(177) LOG(INFO) Running command: --input=./an4/text_corpus/document.txt --model_prefix=./an4/tokenizer_spe_unigram_v128/tokenizer --vocab_size=128 --shuffle_input_sentence=true --hard_vocab_limit=false --model_type=unigram --character_coverage=1.0 --bos_id=-1 --eos_id=-1 --normalization_rule_name=nmt_nfkc_cf
# sentencepiece_trainer.cc(77) LOG(INFO) Starts training with :
# trainer_spec {
#   input: ./an4/text_corpus/document.txt
#   input_format:
#   model_prefix: ./an4/tokenizer_spe_unigram_v128/tokenizer
#   model_type: UNIGRAM
#   vocab_size: 128
#   self_test_sample_size: 0
#   character_coverage: 1
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 0
#   treat_whitespace_as_suffix: 0
#   allow_whitespace_only_pieces: 0
#   required_chars:
#   byte_fallback: 0
#   vocabulary_output_piece_score: 1
#   train_extremely_large_corpus: 0
#   hard_vocab_limit: 0
#   use_all_vocab: 0
#   unk_id: 0
#   bos_id: -1
#   eos_id: -1
#   pad_id: -1
#   unk_piece: <unk>
#   bos_piece: <s>
#   eos_piece: </s>
#   pad_piece: <pad>
#   unk_surface:  ⁇
#   enable_differential_privacy: 0
#   differential_privacy_noise_level: 0
#   differential_privacy_clipping_threshold: 0
# }
# normalizer_spec {
#   name: nmt_nfkc_cf
#   add_dummy_prefix: 1
#   remove_extra_whitespaces: 1
#   escape_whitespaces: 1
#   normalization_rule_tsv:
# }
# denormalizer_spec {}
# trainer_interface.cc(350) LOG(INFO) SentenceIterator is not specified. Using MultiFileSentenceIterator.
# trainer_interface.cc(181) LOG(INFO) Loading corpus: ./an4/text_corpus/document.txt
# trainer_interface.cc(406) LOG(INFO) Loaded all 948 sentences
# trainer_interface.cc(422) LOG(INFO) Adding meta_piece: <unk>
# trainer_interface.cc(427) LOG(INFO) Normalizing sentences...
# trainer_interface.cc(536) LOG(INFO) all chars count=18802
# trainer_interface.cc(557) LOG(INFO) Alphabet size=27
# trainer_interface.cc(558) LOG(INFO) Final character coverage=1
# trainer_interface.cc(590) LOG(INFO) Done! preprocessed 948 sentences.
# unigram_model_trainer.cc(146) LOG(INFO) Making suffix array...
# unigram_model_trainer.cc(150) LOG(INFO) Extracting frequent sub strings...
# unigram_model_trainer.cc(201) LOG(INFO) Initialized 247 seed sentencepieces
# trainer_interface.cc(596) LOG(INFO) Tokenizing input sentences with whitespace: 948
# trainer_interface.cc(607) LOG(INFO) Done! 99
# unigram_model_trainer.cc(491) LOG(INFO) Using 99 sentences for EM training
# unigram_model_trainer.cc(507) LOG(INFO) EM sub_iter=0 size=158 obj=6.00125 num_tokens=203 num_tokens/piece=1.28481
# unigram_model_trainer.cc(507) LOG(INFO) EM sub_iter=1 size=126 obj=4.95207 num_tokens=204 num_tokens/piece=1.61905
# trainer_interface.cc(685) LOG(INFO) Saving model: ./an4/tokenizer_spe_unigram_v128/tokenizer.model
# trainer_interface.cc(697) LOG(INFO) Saving vocabs: ./an4/tokenizer_spe_unigram_v128/tokenizer.vocab
# Serialized tokenizer at location : ./an4/tokenizer_spe_unigram_v128

# %% [markdown]
# #### Training Conformer-CTC
#
# NeMo uses configuartion files to configure the training parameters. You may update them directly by editing the configuration file or from the command-line interface. For example, if the number of epochs are needed to be modified along with a change in the learning rate, you can add `trainer.max_epochs=100` and `optim.lr=0.02` and train the model.
#
# The following sample command would use the script `speech_to_text_ctc_bpe.py` in the example folder to train/fine-tune a Conformer-CTC ASR model for 100 epochs. For other ASR models like Citrinet, you may find the appropiate config files under the NeMo/examples/asr/conf/.

# %%
# To fully train the model from scratch, you'll need to increase trainer.max_epochs from 1
# Empirical evidence suggests that around 200 epochs should suffice
# !python $NEMO_DIR/examples/asr/asr_ctc/speech_to_text_ctc_bpe.py \
    --config-path=../conf/conformer/ --config-name=conformer_ctc_bpe \
    +init_from_pretrained_model=stt_en_conformer_ctc_large \
    model.train_ds.manifest_filepath=$DATA_DIR/an4_converted/train_manifest.json \
    model.validation_ds.manifest_filepath=$DATA_DIR/an4_converted/test_manifest.json \
    model.tokenizer.dir=$DATA_DIR/an4/tokenizer_spe_unigram_v128 \
    trainer.devices=1 \
    trainer.max_epochs=1 \
    model.optim.name="adamw" \
    model.optim.lr=1.0 \
    model.optim.weight_decay=0.001 \
    model.optim.sched.warmup_steps=2000 \
    ++exp_manager.exp_dir=$DATA_DIR/checkpoints \
    ++exp_manager.version=test \
    ++exp_manager.use_datetime_version=False
# Out:
# [NeMo W 2023-01-18 18:47:56 optimizers:55] Apex was not found. Using the lamb or fused_adam optimizer will error out.
# [NeMo W 2023-01-18 18:47:57 experimental:27] Module <class 'nemo.collections.asr.models.audio_to_audio_model.AudioToAudioModel'> is experimental, not ready for production and is not fully supported. Use at your own risk.
# [NeMo W 2023-01-18 18:47:58 experimental:27] Module <class 'nemo.collections.asr.modules.audio_modules.SpectrogramToMultichannelFeatures'> is experimental, not ready for production and is not fully supported. Use at your own risk.
# [NeMo W 2023-01-18 18:47:58 nemo_logging:349] /usr/local/lib/python3.8/dist-packages/torch/jit/annotations.py:309: UserWarning: TorchScript will treat type annotations of Tensor dtype-specific subtypes as if they are normal Tensors. dtype constraints are not enforced in compilation either.
#       warnings.warn("TorchScript will treat type annotations of Tensor "
#
# [NeMo W 2023-01-18 18:47:58 experimental:27] Module <class 'nemo.collections.asr.data.audio_to_audio.BaseAudioDataset'> is experimental, not ready for production and is not fully supported. Use at your own risk.
# [NeMo W 2023-01-18 18:47:58 experimental:27] Module <class 'nemo.collections.asr.data.audio_to_audio.AudioToTargetDataset'> is experimental, not ready for production and is not fully supported. Use at your own risk.
# [NeMo W 2023-01-18 18:47:58 experimental:27] Module <class 'nemo.collections.asr.data.audio_to_audio.AudioToTargetWithReferenceDataset'> is experimental, not ready for production and is not fully supported. Use at your own risk.
# [NeMo W 2023-01-18 18:47:58 experimental:27] Module <class 'nemo.collections.asr.data.audio_to_audio.AudioToTargetWithEmbeddingDataset'> is experimental, not ready for production and is not fully supported. Use at your own risk.
# [NeMo W 2023-01-18 18:47:58 experimental:27] Module <class 'nemo.collections.asr.models.enhancement_models.EncMaskDecAudioToAudioModel'> is experimental, not ready for production and is not fully supported. Use at your own risk.
# [NeMo W 2023-01-18 18:47:59 nemo_logging:349] /usr/local/lib/python3.8/dist-packages/hydra/_internal/hydra.py:119: UserWarning: Future Hydra versions will no longer change working directory at job runtime by default.
#     See https://hydra.cc/docs/next/upgrades/1.1_to_1.2/changes_to_job_working_dir/ for more information.
#       ret = run_job(
#
# [NeMo I 2023-01-18 18:47:59 speech_to_text_ctc_bpe:78] Hydra config: name: Conformer-CTC-BPE
#     model:
#       sample_rate: 16000
#       log_prediction: true
#       ctc_reduction: mean_batch
#       skip_nan_grad: false
#       train_ds:
#         manifest_filepath: ./an4_converted/train_manifest.json
#         sample_rate: ${model.sample_rate}
#         batch_size: 16
#         shuffle: true
#         num_workers: 8
#         pin_memory: true
#         use_start_end_token: false
#         trim_silence: false
#         max_duration: 16.7
#         min_duration: 0.1
#         is_tarred: false
#         tarred_audio_filepaths: null
#         shuffle_n: 2048
#         bucketing_strategy: synced_randomized
#         bucketing_batch_size: null
#       validation_ds:
#         manifest_filepath: ./an4_converted/test_manifest.json
#         sample_rate: ${model.sample_rate}
#         batch_size: 16
#         shuffle: false
#         num_workers: 8
#         pin_memory: true
#         use_start_end_token: false
#       test_ds:
#         manifest_filepath: null
#         sample_rate: ${model.sample_rate}
#         batch_size: 16
#         shuffle: false
#         num_workers: 8
#         pin_memory: true
#         use_start_end_token: false
#       tokenizer:
#         dir: ./an4/tokenizer_spe_unigram_v128
#         type: bpe
#       preprocessor:
#         _target_: nemo.collections.asr.modules.AudioToMelSpectrogramPreprocessor
#         sample_rate: ${model.sample_rate}
#         normalize: per_feature
#         window_size: 0.025
#         window_stride: 0.01
#         window: hann
#         features: 80
#         n_fft: 512
#         log: true
#         frame_splicing: 1
#         dither: 1.0e-05
#         pad_to: 0
#         pad_value: 0.0
#       spec_augment:
#         _target_: nemo.collections.asr.modules.SpectrogramAugmentation
#         freq_masks: 2
#         time_masks: 10
#         freq_width: 27
#         time_width: 0.05
#       encoder:
#         _target_: nemo.collections.asr.modules.ConformerEncoder
#         feat_in: ${model.preprocessor.features}
#         feat_out: -1
#         n_layers: 18
#         d_model: 512
#         subsampling: striding
#         subsampling_factor: 4
#         subsampling_conv_channels: -1
#         causal_downsampling: false
#         ff_expansion_factor: 4
#         self_attention_model: rel_pos
#         n_heads: 8
#         att_context_size:
#         - -1
#         - -1
#         att_context_style: regular
#         xscaling: true
#         untie_biases: true
#         pos_emb_max_len: 5000
#         conv_kernel_size: 31
#         conv_norm_type: batch_norm
#         conv_context_size: null
#         dropout: 0.1
#         dropout_pre_encoder: 0.1
#         dropout_emb: 0.0
#         dropout_att: 0.1
#       decoder:
#         _target_: nemo.collections.asr.modules.ConvASRDecoder
#         feat_in: null
#         num_classes: -1
#         vocabulary: []
#       optim:
#         name: adamw
#         lr: 1.0
#         betas:
#         - 0.9
#         - 0.98
#         weight_decay: 0.001
#         sched:
#           name: NoamAnnealing
#           d_model: ${model.encoder.d_model}
#           warmup_steps: 2000
#           warmup_ratio: null
#           min_lr: 1.0e-06
#     trainer:
#       devices: 1
#       num_nodes: 1
#       max_epochs: 1
#       max_steps: -1
#       val_check_interval: 1.0
#       accelerator: auto
#       strategy: ddp
#       accumulate_grad_batches: 1
#       gradient_clip_val: 0.0
#       precision: 32
#       log_every_n_steps: 10
#       enable_progress_bar: true
#       resume_from_checkpoint: null
#       num_sanity_val_steps: 0
#       check_val_every_n_epoch: 1
#       sync_batchnorm: true
#       enable_checkpointing: false
#       logger: false
#       benchmark: false
#     exp_manager:
#       exp_dir: ./
#       name: ${name}
#       create_tensorboard_logger: true
#       create_checkpoint_callback: true
#       checkpoint_callback_params:
#         monitor: val_wer
#         mode: min
#         save_top_k: 5
#         always_save_nemo: true
#       resume_if_exists: false
#       resume_ignore_no_checkpoint: false
#       create_wandb_logger: false
#       wandb_logger_kwargs:
#         name: null
#         project: null
#       version: test
#       use_datetime_version: false
#     init_from_pretrained_model: stt_en_conformer_ctc_large
#
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# `Trainer(val_check_interval=1.0)` was configured so validation will run at the end of the training epoch..
# [NeMo I 2023-01-18 18:47:59 exp_manager:361] Experiments will be logged at Conformer-CTC-BPE/test
# [NeMo I 2023-01-18 18:47:59 exp_manager:766] TensorboardLogger has been set up
# [NeMo I 2023-01-18 18:47:59 mixins:170] Tokenizer SentencePieceTokenizer initialized with 128 tokens
# [NeMo I 2023-01-18 18:48:00 ctc_bpe_models:64]
#     Replacing placeholder number of classes (-1) with actual number of classes - 128
# [NeMo I 2023-01-18 18:48:00 collections:193] Dataset loaded with 948 files totalling 0.71 hours
# [NeMo I 2023-01-18 18:48:00 collections:194] 0 files were filtered totalling 0.00 hours
# [NeMo W 2023-01-18 18:48:00 nemo_logging:349] /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:554: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#       warnings.warn(_create_warning_msg(
#
# [NeMo I 2023-01-18 18:48:00 collections:193] Dataset loaded with 130 files totalling 0.10 hours
# [NeMo I 2023-01-18 18:48:00 collections:194] 0 files were filtered totalling 0.00 hours
# [NeMo W 2023-01-18 18:48:00 ctc_bpe_models:164] Could not load dataset as `manifest_filepath` was None. Provided config : {'manifest_filepath': None, 'sample_rate': 16000, 'batch_size': 16, 'shuffle': False, 'num_workers': 8, 'pin_memory': True, 'use_start_end_token': False}
# [NeMo I 2023-01-18 18:48:00 features:267] PADDING: 0
# [NeMo I 2023-01-18 18:48:01 audio_preprocessing:513] Numba CUDA SpecAugment kernel is being used
# [NeMo I 2023-01-18 18:48:01 cloud:66] Downloading from: https://api.ngc.nvidia.com/v2/models/nvidia/nemo/stt_en_conformer_ctc_large/versions/1.10.0/files/stt_en_conformer_ctc_large.nemo to /root/.cache/torch/NeMo/NeMo_1.15.0rc0/stt_en_conformer_ctc_large/afb212c5bcf904e326b5e5751e7c7465/stt_en_conformer_ctc_large.nemo
# [NeMo I 2023-01-18 18:48:53 common:913] Instantiating model from pre-trained checkpoint
# [NeMo I 2023-01-18 18:48:54 mixins:170] Tokenizer SentencePieceTokenizer initialized with 128 tokens
# [NeMo W 2023-01-18 18:48:54 modelPT:156] If you intend to do training or fine-tuning, please call the ModelPT.setup_training_data() method and provide a valid configuration file to setup the train data loader.
#     Train config :
#     manifest_filepath:
#     - - /data2/nemo_asr/nemo_asr_set_3.0/bucket1/tarred_audio_manifest.json
#     - - /data2/nemo_asr/nemo_asr_set_3.0/bucket2/tarred_audio_manifest.json
#     - - /data2/nemo_asr/nemo_asr_set_3.0/bucket3/tarred_audio_manifest.json
#     - - /data2/nemo_asr/nemo_asr_set_3.0/bucket4/tarred_audio_manifest.json
#     - - /data2/nemo_asr/nemo_asr_set_3.0/bucket5/tarred_audio_manifest.json
#     - - /data2/nemo_asr/nemo_asr_set_3.0/bucket6/tarred_audio_manifest.json
#     - - /data2/nemo_asr/nemo_asr_set_3.0/bucket7/tarred_audio_manifest.json
#     - - /data2/nemo_asr/nemo_asr_set_3.0/bucket8/tarred_audio_manifest.json
#     sample_rate: 16000
#     batch_size: 1
#     shuffle: true
#     num_workers: 4
#     pin_memory: true
#     use_start_end_token: false
#     trim_silence: false
#     max_duration: 20.0
#     min_duration: 0.1
#     is_tarred: true
#     tarred_audio_filepaths:
#     - - /data2/nemo_asr/nemo_asr_set_3.0/bucket1/audio__OP_0..8191_CL_.tar
#     - - /data2/nemo_asr/nemo_asr_set_3.0/bucket2/audio__OP_0..8191_CL_.tar
#     - - /data2/nemo_asr/nemo_asr_set_3.0/bucket3/audio__OP_0..8191_CL_.tar
#     - - /data2/nemo_asr/nemo_asr_set_3.0/bucket4/audio__OP_0..8191_CL_.tar
#     - - /data2/nemo_asr/nemo_asr_set_3.0/bucket5/audio__OP_0..8191_CL_.tar
#     - - /data2/nemo_asr/nemo_asr_set_3.0/bucket6/audio__OP_0..8191_CL_.tar
#     - - /data2/nemo_asr/nemo_asr_set_3.0/bucket7/audio__OP_0..8191_CL_.tar
#     - - /data2/nemo_asr/nemo_asr_set_3.0/bucket8/audio__OP_0..8191_CL_.tar
#     shuffle_n: 2048
#     bucketing_strategy: synced_randomized
#     bucketing_batch_size:
#     - 34
#     - 30
#     - 26
#     - 22
#     - 18
#     - 16
#     - 12
#     - 8
#
# [NeMo W 2023-01-18 18:48:54 modelPT:163] If you intend to do validation, please call the ModelPT.setup_validation_data() or ModelPT.setup_multiple_validation_data() method and provide a valid configuration file to setup the validation data loader(s).
#     Validation config :
#     manifest_filepath:
#     - /manifests/librispeech/librivox-dev-other.json
#     - /manifests/librispeech/librivox-dev-clean.json
#     - /manifests/librispeech/librivox-test-other.json
#     - /manifests/librispeech/librivox-test-clean.json
#     sample_rate: 16000
#     batch_size: 32
#     shuffle: false
#     num_workers: 8
#     pin_memory: true
#     use_start_end_token: false
#
# [NeMo W 2023-01-18 18:48:54 modelPT:169] Please call the ModelPT.setup_test_data() or ModelPT.setup_multiple_test_data() method and provide a valid configuration file to setup the test data loader(s).
#     Test config :
#     manifest_filepath:
#     - /manifests/librispeech/librivox-dev-other.json
#     - /manifests/librispeech/librivox-dev-clean.json
#     - /manifests/librispeech/librivox-test-other.json
#     - /manifests/librispeech/librivox-test-clean.json
#     sample_rate: 16000
#     batch_size: 32
#     shuffle: false
#     num_workers: 8
#     pin_memory: true
#     use_start_end_token: false
#
# [NeMo I 2023-01-18 18:48:54 features:267] PADDING: 0
# [NeMo I 2023-01-18 18:48:56 audio_preprocessing:513] Numba CUDA SpecAugment kernel is being used
# [NeMo I 2023-01-18 18:48:56 save_restore_connector:243] Model EncDecCTCModelBPE was successfully restored from /root/.cache/torch/NeMo/NeMo_1.15.0rc0/stt_en_conformer_ctc_large/afb212c5bcf904e326b5e5751e7c7465/stt_en_conformer_ctc_large.nemo.
# [NeMo I 2023-01-18 18:48:56 modelPT:1163] Model checkpoint restored from pretrained checkpoint with name : `stt_en_conformer_ctc_large`
# Initializing distributed: GLOBAL_RANK: 0, MEMBER: 1/1
# Added key: store_based_barrier_key:1 to store for rank: 0
# Rank 0: Completed store-based barrier for key:store_based_barrier_key:1 with 1 nodes.
# ----------------------------------------------------------------------------------------------------
# distributed_backend=nccl
# All distributed processes registered. Starting with 1 processes
# ----------------------------------------------------------------------------------------------------
#
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# [NeMo I 2023-01-18 18:49:01 modelPT:616] Optimizer config = AdamW (
#     Parameter Group 0
#         amsgrad: False
#         betas: [0.9, 0.98]
#         capturable: False
#         eps: 1e-08
#         foreach: None
#         lr: 1.0
#         maximize: False
#         weight_decay: 0.001
#     )
# [NeMo I 2023-01-18 18:49:01 lr_scheduler:910] Scheduler "<nemo.core.optim.lr_scheduler.NoamAnnealing object at 0x7fd244791ca0>"
#     will be used during training (effective maximum steps = 60) -
#     Parameters :
#     (d_model: 512
#     warmup_steps: 2000
#     warmup_ratio: null
#     min_lr: 1.0e-06
#     max_steps: 60
#     )
#
#   | Name              | Type                              | Params
# ------------------------------------------------------------------------
# 0 | preprocessor      | AudioToMelSpectrogramPreprocessor | 0
# 1 | encoder           | ConformerEncoder                  | 121 M
# 2 | decoder           | ConvASRDecoder                    | 66.2 K
# 3 | loss              | CTCLoss                           | 0
# 4 | spec_augmentation | SpectrogramAugmentation           | 0
# 5 | _wer              | WERBPE                            | 0
# ------------------------------------------------------------------------
# 121 M     Trainable params
# 0         Non-trainable params
# 121 M     Total params
# 486.005   Total estimated model params size (MB)
# Epoch 0:   0% 0/69 [00:00<?, ?it/s] [W reducer.cpp:1298] Warning: find_unused_parameters=True was specified in DDP constructor, but did not find any unused parameters in the forward pass. This flag results in an extra traversal of the autograd graph every iteration,  which can adversely affect performance. If your model indeed never has any unused parameters in the forward pass, consider turning this flag off. Note that this warning may be a false positive if your model has flow control causing later iterations to have unused parameters. (function operator())
# Epoch 0:  13% 9/69 [00:15<01:42,  1.71s/it, loss=90.6, v_num=test][NeMo I 2023-01-18 18:49:16 wer_bpe:293]
#
# [NeMo I 2023-01-18 18:49:16 wer_bpe:294] reference:enter two six
# [NeMo I 2023-01-18 18:49:16 wer_bpe:295] predicted:fifteentar f a threeb c one
# Epoch 0:  28% 19/69 [00:23<01:00,  1.22s/it, loss=89.6, v_num=test][NeMo I 2023-01-18 18:49:24 wer_bpe:293]
#
# [NeMo I 2023-01-18 18:49:24 wer_bpe:294] reference:e r i c
# [NeMo I 2023-01-18 18:49:24 wer_bpe:295] predicted:s n thirty n s thirt g
# Epoch 0:  42% 29/69 [00:30<00:41,  1.05s/it, loss=85.6, v_num=test][NeMo I 2023-01-18 18:49:31 wer_bpe:293]
#
# [NeMo I 2023-01-18 18:49:31 wer_bpe:294] reference:r h h u f two
# [NeMo I 2023-01-18 18:49:31 wer_bpe:295] predicted:eper n g e n g e twenty ninp a
# Epoch 0:  57% 39/69 [00:38<00:29,  1.02it/s, loss=81.7, v_num=test][NeMo I 2023-01-18 18:49:39 wer_bpe:293]
#
# [NeMo I 2023-01-18 18:49:39 wer_bpe:294] reference:g i b s o n i a
# [NeMo I 2023-01-18 18:49:39 wer_bpe:295] predicted:st y zero three stea y
# [NeMo I 2023-01-18 18:49:58 wer_bpe:294] reference:m y e r s
# [NeMo I 2023-01-18 18:49:58 wer_bpe:295] predicted:r four fi  l three
#
# Epoch 0:  97% 67/69 [00:56<00:01,  1.18it/s, loss=75.5, v_num=test][NeMo I 2023-01-18 18:49:58 wer_bpe:293]
#
# [NeMo I 2023-01-18 18:49:58 wer_bpe:294] reference:p h i n n e y
# [NeMo I 2023-01-18 18:49:58 wer_bpe:295] predicted:v  seven yeaea  four
#
# Epoch 0:  99% 68/69 [00:57<00:00,  1.19it/s, loss=75.5, v_num=test][NeMo I 2023-01-18 18:49:58 wer_bpe:293]
#
# [NeMo I 2023-01-18 18:49:58 wer_bpe:294] reference:four one two two six eight four one four two
# [NeMo I 2023-01-18 18:49:58 wer_bpe:295] predicted:ru ateenop ear f aar f a threebde fi twentru ateenop eruar f a
#
# Epoch 0: 100% 69/69 [00:57<00:00,  1.21it/s, loss=75.5, v_num=test][NeMo W 2023-01-18 18:49:58 nemo_logging:349] /usr/local/lib/python3.8/dist-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:537: PossibleUserWarning: It is recommended to use `self.log('global_step', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
#       warning_cache.warn(
#
# [NeMo W 2023-01-18 18:49:58 nemo_logging:349] /usr/local/lib/python3.8/dist-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:537: PossibleUserWarning: It is recommended to use `self.log('val_loss', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
#       warning_cache.warn(
#
# [NeMo W 2023-01-18 18:49:58 nemo_logging:349] /usr/local/lib/python3.8/dist-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:537: PossibleUserWarning: It is recommended to use `self.log('val_wer', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
#       warning_cache.warn(
#
# Epoch 0: 100% 69/69 [00:57<00:00,  1.21it/s, loss=75.5, v_num=test]
# Epoch 0: 100% 69/69 [00:57<00:00,  1.21it/s, loss=75.5, v_num=test]Epoch 0, global step 60: 'val_wer' reached 1.35705 (best 1.35705), saving model to '/content/Conformer-CTC-BPE/test/checkpoints/Conformer-CTC-BPE--val_wer=1.3571-epoch=0.ckpt' as top 5
# tcmalloc: large alloc 1232969728 bytes == 0x13a06e000 @  0x7fd2fd25e680 0x7fd2fd27eda2 0x5f714c 0x64d800 0x527022 0x5c4520 0x5f6eb7 0x7fd2db442795 0x7fd2db59aeeb 0x7fd2b494bc45 0x7fd2b4945728 0x7fd2b494d2c9 0x7fd2db5ae9ca 0x7fd2db195f00 0x5f5b39 0x5f6706 0x50ba83 0x570b82 0x569d8a 0x5f60c3 0x56bab6 0x569d8a 0x5f60c3 0x570b82 0x5f5ee6 0x56bab6 0x569d8a 0x50b3a0 0x56cc92 0x569d8a 0x50b3a0
# tcmalloc: large alloc 1541218304 bytes == 0xc4f58000 @  0x7fd2fd25e680 0x7fd2fd27eda2 0x5f714c 0x64d800 0x527022 0x5c4520 0x5f6eb7 0x7fd2db442795 0x7fd2db59aeeb 0x7fd2b494bc45 0x7fd2b4945728 0x7fd2b494d2c9 0x7fd2db5ae9ca 0x7fd2db195f00 0x5f5b39 0x5f6706 0x50ba83 0x570b82 0x569d8a 0x5f60c3 0x56bab6 0x569d8a 0x5f60c3 0x570b82 0x5f5ee6 0x56bab6 0x569d8a 0x50b3a0 0x56cc92 0x569d8a 0x50b3a0
# tcmalloc: large alloc 1541218304 bytes == 0xc4f58000 @  0x7fd2fd25e680 0x7fd2fd27eda2 0x5f714c 0x64d800 0x527022 0x5c4520 0x5f6eb7 0x7fd2db442795 0x7fd2db59aeeb 0x7fd2b494bc45 0x7fd2b4945728 0x7fd2b494d2c9 0x7fd2db5ae9ca 0x7fd2db195f00 0x5f5b39 0x5f6706 0x50ba83 0x570b82 0x569d8a 0x5f60c3 0x56bab6 0x569d8a 0x5f60c3 0x570b82 0x5f5ee6 0x56bab6 0x569d8a 0x50b3a0 0x56cc92 0x569d8a 0x50b3a0
# `Trainer.fit` stopped: `max_epochs=1` reached.
# Epoch 0: 100% 69/69 [01:25<00:00,  1.24s/it, loss=75.5, v_num=test]
# tcmalloc: large alloc 1541218304 bytes == 0xc4f58000 @  0x7fd2fd25e680 0x7fd2fd27eda2 0x5f714c 0x64d800 0x527022 0x5c4520 0x5f6eb7 0x7fd2db442795 0x7fd2db59aeeb 0x7fd2b494bc45 0x7fd2b4945728 0x7fd2b494d2c9 0x7fd2db5ae9ca 0x7fd2db195f00 0x5f5b39 0x5f6706 0x50ba83 0x570b82 0x569d8a 0x5f60c3 0x56bab6 0x569d8a 0x5f60c3 0x570b82 0x5f5ee6 0x56bab6 0x569d8a 0x50b3a0 0x56cc92 0x569d8a 0x50b3a0

# %%
# !ls ./Conformer-CTC-BPE/test/checkpoints/
# Out:
#  Conformer-CTC-BPE.nemo
# 'Conformer-CTC-BPE--val_wer=1.3571-epoch=0.ckpt'
# 'Conformer-CTC-BPE--val_wer=1.3571-epoch=1-last.ckpt'

# %%
nemo_file_path = os.path.join(DATA_DIR, 'checkpoints/Conformer-CTC-BPE/test/checkpoints/Conformer-CTC-BPE.nemo')

# %% [markdown]
# ### ASR Evaluation

# %% [markdown]
# Now that we have a model trained, we need to check how well it performs.

# %%
# !python $NEMO_DIR/examples/asr/speech_to_text_eval.py \
    model_path=$nemo_file_path \
    dataset_manifest=$DATA_DIR/an4_converted/test_manifest.json \
    output_filename=./test_manifest_predictions.json \
    batch_size=32 \
    amp=True
# Out:
# [NeMo W 2023-01-18 18:50:53 optimizers:55] Apex was not found. Using the lamb or fused_adam optimizer will error out.
# [NeMo W 2023-01-18 18:50:54 experimental:27] Module <class 'nemo.collections.asr.models.audio_to_audio_model.AudioToAudioModel'> is experimental, not ready for production and is not fully supported. Use at your own risk.
# [NeMo W 2023-01-18 18:50:56 experimental:27] Module <class 'nemo.collections.asr.modules.audio_modules.SpectrogramToMultichannelFeatures'> is experimental, not ready for production and is not fully supported. Use at your own risk.
# [NeMo W 2023-01-18 18:50:56 nemo_logging:349] /usr/local/lib/python3.8/dist-packages/torch/jit/annotations.py:309: UserWarning: TorchScript will treat type annotations of Tensor dtype-specific subtypes as if they are normal Tensors. dtype constraints are not enforced in compilation either.
#       warnings.warn("TorchScript will treat type annotations of Tensor "
#
# [NeMo W 2023-01-18 18:50:57 experimental:27] Module <class 'nemo.collections.asr.data.audio_to_audio.BaseAudioDataset'> is experimental, not ready for production and is not fully supported. Use at your own risk.
# [NeMo W 2023-01-18 18:50:57 experimental:27] Module <class 'nemo.collections.asr.data.audio_to_audio.AudioToTargetDataset'> is experimental, not ready for production and is not fully supported. Use at your own risk.
# [NeMo W 2023-01-18 18:50:57 experimental:27] Module <class 'nemo.collections.asr.data.audio_to_audio.AudioToTargetWithReferenceDataset'> is experimental, not ready for production and is not fully supported. Use at your own risk.
# [NeMo W 2023-01-18 18:50:57 experimental:27] Module <class 'nemo.collections.asr.data.audio_to_audio.AudioToTargetWithEmbeddingDataset'> is experimental, not ready for production and is not fully supported. Use at your own risk.
# [NeMo W 2023-01-18 18:50:57 experimental:27] Module <class 'nemo.collections.asr.models.enhancement_models.EncMaskDecAudioToAudioModel'> is experimental, not ready for production and is not fully supported. Use at your own risk.
# [NeMo W 2023-01-18 18:50:57 nemo_logging:349] /usr/local/lib/python3.8/dist-packages/hydra/_internal/hydra.py:119: UserWarning: Future Hydra versions will no longer change working directory at job runtime by default.
#     See https://hydra.cc/docs/next/upgrades/1.1_to_1.2/changes_to_job_working_dir/ for more information.
#       ret = run_job(
#
# [NeMo I 2023-01-18 18:50:57 transcribe_speech:152] Hydra config: model_path: ./Conformer-CTC-BPE/test/checkpoints/Conformer-CTC-BPE.nemo
#     pretrained_name: null
#     audio_dir: null
#     dataset_manifest: ./an4_converted/test_manifest.json
#     channel_selector: null
#     audio_key: audio_filepath
#     eval_config_yaml: null
#     output_filename: ./test_manifest_predictions.json
#     batch_size: 32
#     num_workers: 0
#     append_pred: false
#     pred_name_postfix: null
#     random_seed: null
#     compute_timestamps: false
#     compute_langs: false
#     cuda: null
#     amp: true
#     audio_type: wav
#     overwrite_transcripts: true
#     ctc_decoding:
#       strategy: greedy
#       preserve_alignments: null
#       compute_timestamps: null
#       word_seperator: ' '
#       ctc_timestamp_type: all
#       batch_dim_index: 0
#       greedy:
#         preserve_alignments: false
#         compute_timestamps: false
#         preserve_frame_confidence: false
#         confidence_method_cfg: null
#       beam:
#         beam_size: 4
#         search_type: default
#         preserve_alignments: false
#         compute_timestamps: false
#         return_best_hypothesis: true
#         beam_alpha: 1.0
#         beam_beta: 0.0
#         kenlm_path: null
#         flashlight_cfg:
#           lexicon_path: null
#           beam_size_token: 16
#           beam_threshold: 20.0
#           unk_weight: -.inf
#           sil_weight: 0.0
#           unit_lm: false
#       confidence_cfg:
#         preserve_frame_confidence: false
#         preserve_token_confidence: false
#         preserve_word_confidence: false
#         exclude_blank: true
#         aggregation: min
#         method_cfg:
#           name: entropy
#           entropy_type: tsallis
#           temperature: 0.33
#           entropy_norm: exp
#     rnnt_decoding:
#       strategy: greedy_batch
#       compute_hypothesis_token_set: false
#       preserve_alignments: null
#       confidence_cfg:
#         preserve_frame_confidence: false
#         preserve_token_confidence: false
#         preserve_word_confidence: false
#         exclude_blank: true
#         aggregation: min
#         method_cfg:
#           name: entropy
#           entropy_type: tsallis
#           temperature: 0.33
#           entropy_norm: exp
#       fused_batch_size: -1
#       compute_timestamps: null
#       compute_langs: false
#       word_seperator: ' '
#       rnnt_timestamp_type: all
#       greedy:
#         max_symbols_per_step: 10
#         preserve_alignments: false
#         preserve_frame_confidence: false
#         confidence_method_cfg: null
#       beam:
#         beam_size: 4
#         search_type: default
#         score_norm: true
#         return_best_hypothesis: true
#         tsd_max_sym_exp_per_step: 50
#         alsd_max_target_len: 1.0
#         nsc_max_timesteps_expansion: 1
#         nsc_prefix_alpha: 1
#         maes_num_steps: 2
#         maes_prefix_alpha: 1
#         maes_expansion_gamma: 2.3
#         maes_expansion_beta: 2
#         language_model: null
#         softmax_temperature: 1.0
#         preserve_alignments: false
#     decoder_type: null
#     model_change:
#       conformer:
#         self_attention_model: null
#         att_context_size: null
#     use_cer: false
#     tolerance: null
#     only_score_manifest: false
#
# [NeMo I 2023-01-18 18:50:58 transcribe_speech:184] Inference will be done on device : [0]
# [NeMo I 2023-01-18 18:50:59 transcribe_utils:185] Restoring model : EncDecCTCModelBPE
# [NeMo I 2023-01-18 18:51:01 mixins:170] Tokenizer SentencePieceTokenizer initialized with 128 tokens
# [NeMo W 2023-01-18 18:51:01 modelPT:156] If you intend to do training or fine-tuning, please call the ModelPT.setup_training_data() method and provide a valid configuration file to setup the train data loader.
#     Train config :
#     manifest_filepath: ./an4_converted/train_manifest.json
#     sample_rate: 16000
#     batch_size: 16
#     shuffle: true
#     num_workers: 8
#     pin_memory: true
#     use_start_end_token: false
#     trim_silence: false
#     max_duration: 16.7
#     min_duration: 0.1
#     is_tarred: false
#     tarred_audio_filepaths: null
#     shuffle_n: 2048
#     bucketing_strategy: synced_randomized
#     bucketing_batch_size: null
#
# [NeMo W 2023-01-18 18:51:01 modelPT:163] If you intend to do validation, please call the ModelPT.setup_validation_data() or ModelPT.setup_multiple_validation_data() method and provide a valid configuration file to setup the validation data loader(s).
#     Validation config :
#     manifest_filepath: ./an4_converted/test_manifest.json
#     sample_rate: 16000
#     batch_size: 16
#     shuffle: false
#     num_workers: 8
#     pin_memory: true
#     use_start_end_token: false
#
# [NeMo W 2023-01-18 18:51:01 modelPT:169] Please call the ModelPT.setup_test_data() or ModelPT.setup_multiple_test_data() method and provide a valid configuration file to setup the test data loader(s).
#     Test config :
#     manifest_filepath: null
#     sample_rate: 16000
#     batch_size: 16
#     shuffle: false
#     num_workers: 8
#     pin_memory: true
#     use_start_end_token: false
#
# [NeMo I 2023-01-18 18:51:01 features:267] PADDING: 0
# [NeMo I 2023-01-18 18:51:02 audio_preprocessing:513] Numba CUDA SpecAugment kernel is being used
# [NeMo I 2023-01-18 18:51:07 save_restore_connector:243] Model EncDecCTCModelBPE was successfully restored from /content/Conformer-CTC-BPE/test/checkpoints/Conformer-CTC-BPE.nemo.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# [NeMo I 2023-01-18 18:51:08 ctc_bpe_models:374] Changed decoding strategy to
#     strategy: greedy
#     preserve_alignments: null
#     compute_timestamps: false
#     word_seperator: ' '
#     ctc_timestamp_type: all
#     batch_dim_index: 0
#     greedy:
#       preserve_alignments: false
#       compute_timestamps: false
#       preserve_frame_confidence: false
#       confidence_method_cfg: null
#     beam:
#       beam_size: 4
#       search_type: default
#       preserve_alignments: false
#       compute_timestamps: false
#       return_best_hypothesis: true
#       beam_alpha: 1.0
#       beam_beta: 0.0
#       kenlm_path: null
#       flashlight_cfg:
#         lexicon_path: null
#         beam_size_token: 16
#         beam_threshold: 20.0
#         unk_weight: -.inf
#         sil_weight: 0.0
#         unit_lm: false
#     confidence_cfg:
#       preserve_frame_confidence: false
#       preserve_token_confidence: false
#       preserve_word_confidence: false
#       exclude_blank: true
#       aggregation: min
#       method_cfg:
#         name: entropy
#         entropy_type: tsallis
#         temperature: 0.33
#         entropy_norm: exp
#
# [NeMo I 2023-01-18 18:51:08 transcribe_utils:234]
#     Transcribing 130 files...
#
# [NeMo I 2023-01-18 18:51:08 transcribe_speech:237] AMP enabled!
#
# Transcribing: 100% 5/5 [00:02<00:00,  1.72it/s]
# [NeMo I 2023-01-18 18:51:11 transcribe_speech:292] Finished transcribing 130 files !
# [NeMo I 2023-01-18 18:51:11 transcribe_speech:293] Writing transcriptions into file: ./test_manifest_predictions.json
# [NeMo I 2023-01-18 18:51:11 transcribe_speech:308] Finished writing predictions to ./test_manifest_predictions.json!
# [NeMo I 2023-01-18 18:51:11 speech_to_text_eval:108] Finished transcribing speech dataset. Computing ASR metrics..
# [NeMo I 2023-01-18 18:51:11 speech_to_text_eval:145] Got WER of 1.3544631306597672

# %% [markdown]
# ### ASR Model Export

# %% [markdown]
# With NeMo, you can also export your model in a format that can be deployed using NVIDIA RIVA; a highly performant application framework for multi-modal conversational AI services using GPUs. The same command for exporting to ONNX can be used here. The only small variation is the configuration for `export_format` in the spec file.

# %% [markdown]
# #### Install the packages
#
# We will now install the packages NeMo and nemo2riva. nemo2riva is available on [ngc](https://catalog.ngc.nvidia.com/orgs/nvidia/teams/riva/resources/riva_quickstart/files?version=2.8.1). Make sure you install NGC CLI first before running the following commands.

# %%
# !pip install nvidia-pyindex
# !ngc registry resource download-version "nvidia/riva/riva_quickstart:2.8.1"
# !pip install "riva_quickstart_v2.8.1/nemo2riva-2.8.1-py3-none-any.whl"
# !pip install protobuf==3.20.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting nvidia-pyindex
#   Downloading nvidia-pyindex-1.0.9.tar.gz (10 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: nvidia-pyindex
#   Building wheel for nvidia-pyindex (setup.py) ... done
#   Created wheel for nvidia-pyindex: filename=nvidia_pyindex-1.0.9-py3-none-any.whl size=8413 sha256=58098dffcd21f3d69c1357194c013a18e91bee7d1c8bc81c83d89ed83e3e7765
#   Stored in directory: /root/.cache/pip/wheels/e0/c2/fb/5cf4e1cfaf28007238362cb746fb38fc2dd76348331a748d54
# Successfully built nvidia-pyindex
# Installing collected packages: nvidia-pyindex
# Successfully installed nvidia-pyindex-1.0.9
# /bin/bash: ngc: command not found
# WARNING: Requirement 'riva_quickstart_v2.8.1/nemo2riva-2.8.1-py3-none-any.whl' looks like a filename, but the file does not exist
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/, https://pypi.ngc.nvidia.com
# Processing ./riva_quickstart_v2.8.1/nemo2riva-2.8.1-py3-none-any.whl
# ERROR: Could not install packages due to an OSError: [Errno 2] No such file or directory: '/content/riva_quickstart_v2.8.1/nemo2riva-2.8.1-py3-none-any.whl'
#
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/, https://pypi.ngc.nvidia.com
# Collecting protobuf==3.20.0
#   Downloading protobuf-3.20.0-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 36.1 MB/s eta 0:00:00
# Installing collected packages: protobuf
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.9.2 requires protobuf<3.20,>=3.9.2, but you have protobuf 3.20.0 which is incompatible.
# tensorflow 2.9.2 requires tensorboard<2.10,>=2.9, but you have tensorboard 2.11.2 which is incompatible.
# onnx 1.13.0 requires protobuf<4,>=3.20.2, but you have protobuf 3.20.0 which is incompatible.
# googleapis-common-protos 1.58.0 requires protobuf!=3.20.0,!=3.20.1,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 3.20.0 which is incompatible.
# google-cloud-translate 3.8.4 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 3.20.0 which is incompatible.
# google-cloud-language 2.6.1 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 3.20.0 which is incompatible.
# google-cloud-firestore 2.7.3 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 3.20.0 which is incompatible.
# google-cloud-datastore 2.11.1 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 3.20.0 which is incompatible.
# google-cloud-bigquery 3.4.1 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 3.20.0 which is incompatible.
# google-cloud-bigquery-storage 2.17.0 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 3.20.0 which is incompatible.
# google-api-core 2.11.0 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 3.20.0 which is incompatible.
# Successfully installed protobuf-3.20.0

# %% [markdown]
# #### Convert to RIVA.
#
# Convert the downloaded model to .riva format, we will use encryption key=nemotoriva. Change this while generating .riva models for production.

# %%
riva_file_path = nemo_file_path[:-5]+".riva"
# !nemo2riva --out {riva_file_path} --key=nemotoriva {nemo_file_path}
# Out:
# /bin/bash: nemo2riva: command not found

# %% [markdown]
# ## More Resources
# You may find more info and details on working with NeMo's ASR model here in the tutorials here:
#
# [NeMo Tutorials](https://github.com/NVIDIA/NeMo/tree/main/tutorials/asr)

# %% [markdown]
# ## What's Next?

# %% [markdown]
# You could use NeMo to build custom models for your own applications, and deploy them to Nvidia Riva! To try deploying these models to RIVA, use the text-to-speech-deployment.ipynb as a quick sample.
